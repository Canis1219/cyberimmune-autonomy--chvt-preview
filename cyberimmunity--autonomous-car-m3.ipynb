# %% [markdown]
# # Кибериммунная автономность$\\$Создание конструктивно защищённого автономного наземного транспортного средства$\\$Модуль 3
#
# ## О документе
#
# Версия 1.03
#
# Модуль 3 для регионального этапа соревнований по кибериммунной автономности

# %% [markdown]
# ### Модуль 3. Внедрение блоков функциональной и информационной безопасности
# #### Общая идея
#
# Ключевая идея кибериммунной автономности заключается в том, чтобы уже на этапе проектирования внедрить защиту от кибератак как снаружи, так и изнутри - т.е. через уязвимые бортовые информационные системы.
# Мы исходим из того, что абсолютно защищённых систем не бывает, чем больше и сложнее код, тем проще одним ("плохим") в нём спрятать уязвимости, а другим ("хорошим", но уставшим) эти уязвимости не найти.
#
# Поэтому необходимо сделать так, чтобы наиболее критичный код был отделён от некритичного и протестирован особенно тщательно - таким образом можно снизить вероятность успешной атаки и затруднить задачу атакующим.

# %% [markdown]
# #### Цели и предположения безопасности
#
# ##### Цели безопасности
# Устойчивость кибериммунных систем к атакам выражается в том, что поставленные заказчиком **цели безопасности** (ЦБ) не нарушаются даже в условиях кибератак (снаружи и изнутри).
#
# Для наших автономных машинок заказчиком поставлены следующие ЦБ:
#
# 1. При любых обстоятельствах АНТС осуществляет перемещения в пределах заданных ограничений
#
# 2. При любых обстоятельствах АНТС выполняет только аутентичный (подлинный) маршрут
#
# 3. При любых обстоятельствах АНТС оставляет груз только в авторизованном пункте назначения
#
# Ниже используется цифро-буквенное обозначение целей безопасности - например, ЦБ1 - первая цель безопасности из списка выше.
#
# ##### Предположения безопасности
# При этом заказчик согласовал с разработчиками следующие **предположения безопасности** (ПБ) - утверждения о смежных системах, которые снимают с разработчиков часть задач для обеспечения целей безопасности:
#
# 1. При любых обстоятельствах только авторизованный персонал имеет физический доступ к критическим узлам АНТС
#
# 2. При любых обстоятельствах только аутентичные и авторизованные операторы имеют доступ к системе планирования заданий
#
# 3. Аутентичные и авторизованные операторы обладают необходимой квалификацией и являются благонадёжными (т.е. не пытаются намеренно причинить ущерб системе или третьим лицам, используя доступ к АНТС)
#
# Ниже используется цифро-буквенное обозначение предположений безопасности - например, ПБ1 - первое предположение безопасности из списка выше.

# %% [markdown]
# ### Киберпрепятствия
#
# Прежде чем мы начнём внедрять механизмы безопасности, посмотрим, что произойдёт с нашей машинкой, если бортовые системы начнут вести себя не так, как мы ожидаем.
#
# Для этого активируем специальный режим работы системы управления и снова запустим машинку по тому же маршруту, который был в конце модуля 2.
#
# После инициализации системы управления добавьте следующую строку
# ```python
# control_system.enable_surprises()
# ```

# %% [markdown]
# Но вначале нужно из модуля 2 скопировать сюда ваши текущие наработки, а именно ваши реализации классов коммуникационного шлюза (CommunicationGateway), систему навигации (NavigationSystem), управления (ControlSystem), также будем использовать маршрут, который вы создали.

# %%
from multiprocessing import Queue
from src.communication_gateway import BaseCommunicationGateway
from src.config import CONTROL_SYSTEM_QUEUE_NAME
from src.event_types import Event
from src.config import SERVOS_QUEUE_NAME
from src.control_system import BaseControlSystem
from src.config import CONTROL_SYSTEM_QUEUE_NAME
from src.navigation_system import BaseNavigationSystem

class CommunicationGateway(BaseCommunicationGateway):
    """Класс для реализации логики взаимодействия с системой планирования заданий.
    Работает в отдельном процессе, поэтому создаётся как наследник класса Process.
    """
    def _send_mission_to_consumers(self):
        """Метод для отправки сообщения с маршрутным заданием в систему управления."""
        
        # Получаем имя очереди системы управления
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME

        # Создаём событие с маршрутным заданием
        event = Event(
            source=BaseCommunicationGateway.event_source_name,
            destination=control_q_name,
            operation="set_mission",
            parameters=self._mission
        )

        # Ищем в каталоге нужную очередь
        control_q: Queue = self._queues_dir.get_queue(control_q_name)

        # Отправляем событие в найденную очередь
        control_q.put(event)
        
class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def _send_speed_and_direction_to_consumers(self, speed, direction):
        servos_q_name = SERVOS_QUEUE_NAME # замените на правильное название очереди
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(
            source=BaseControlSystem.event_source_name,
            destination=servos_q_name,
            operation="set_speed",
            parameters=speed
        )                   # замените на код создания сообщения со скоростью для приводов
                            # подсказка, требуемая операция - set_speed

        # отправка сообщения с желаемым направлением
        event_direction = Event(
            source=BaseControlSystem.event_source_name,
            destination=servos_q_name,
            operation="set_direction",
            parameters=direction
        )                       # замените на код создания сообщения с направлением для приводов
                                # подсказка, требуемая операция - set_direction

        servos_q.put(event_speed)
        servos_q.put(event_direction)       

class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):                              
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME # замените на правильное название очереди
        event = Event(
            source=BaseNavigationSystem.event_source_name,
            destination=control_q_name,
            operation="position_update",
            parameters=self._position           # Координаты текущего местоположения
        )                                       # замените на код создания сообщения с координатами для системы управления 
                                                # подсказка, требуемая операция - position_update
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)

# %% [markdown]
# Если у вас настроена и работает СУПА, установите в True значение переменной afcs_present

# %%
afcs_present = True

# %% [markdown]
# Поменяем идентификатор машинки для этого модуля

# %%
car_id = "m3"

# %%
# используем то же маршрутное задание, которое было в модуле 2
from time import sleep
from geopy import Point as GeoPoint

from src.queues_dir import QueuesDirectory
from src.servos import Servos
from src.sitl import SITL
from src.cargo_bay import CargoBay
from src.mission_planner import MissionPlanner
from src.config import LOG_ERROR, LOG_INFO
from src.mission_planner_mqtt import MissionSender
from src.mission_planner import Mission
from src.sitl_mqtt import TelemetrySender
from src.system_wrapper import SystemComponentsContainer
from src.wpl_parser import WPLParser

afcs_present = True

car_id = "m3"

# возьмём маршрут из модуля 2
wpl_file = "module2.wpl"

parser = WPLParser(wpl_file)    
points = parser.parse()
print(points)

from src.mission_type import GeoSpecificSpeedLimit
speed_limits = [
    GeoSpecificSpeedLimit(0, 20),
    GeoSpecificSpeedLimit(2, 60),
    GeoSpecificSpeedLimit(7, 20),
]


home = points[0]
mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)

# каталог очередей для передачи сообщений между блоками
queues_dir = QueuesDirectory() 

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

communication_gateway = CommunicationGateway(
    queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)

navigation_system = NavigationSystem(
    queues_dir=queues_dir, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

# по аналогии собираем все блоки в одном кузове
system_components = SystemComponentsContainer(
    components=[
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system
    ] if afcs_present else [
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system
    ])

#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
#################################

system_components.start()

# ограничение поездки по времени
# параметр sleep - время в секундах,
# настройте этот параметр так, чтобы ваша машинка завершила маршрут
# в случае превышения времени выполнения ячейки на более чем 10 секунд от заданного, 
# допустимо перезапустить вычислительное ядро и повторно выполнить весь блокнот, штрафные очки за это не начисляются
# при условии, что повторный запуск закончился успешно
sleep(5)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
del system_components
# Out:
# [Point(59.869328, 29.827365, 0.0), Point(59.868883, 29.824322, 0.0), Point(59.869184, 29.823516, 0.0), Point(59.870481, 29.828145, 0.0), Point(59.870456, 29.836566, 0.0), Point(59.869963, 29.844628, 0.0), Point(59.869206, 29.848098, 0.0), Point(59.870235, 29.849917, 0.0), Point(59.870743, 29.849644, 0.0), Point(59.871044, 29.849363, 0.0)]
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][CONTROL] старт системы управления
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 20:13:31.922729
# [ИНФО][CONTROL] новая скорость 20 (была 0)
# [ИНФО][CONTROL] новое направление 253 (было 0)

# %% [markdown]
# Итак, в отличие от, надеемся, успешного завершения маршрута в модуле 2, сейчас ваша машинка ведёт себя совсем иначе. Например, она внезапно едет в совершенно другую сторону (это особенно хорошо видно при использовании СУПА).
# И это ещё не всё, что может пойти не так..
#
# В этой реализации не очень много кода, теоретически, вы можете его весь изучить и устранить "незадокументированные возможности", однако в реальных системах кода гораздо больше. Например, кодовая база проекта с открытым исходным кодом ArduPilot, реализующего в том числе логику автопилота, составляет примерно миллион строк.
#
# Сколько времени вам понадобится, чтобы изучить и протестировать миллион строк кода? А ведь придётся проводить анализ и каждого обновления.. При этом неприятности могут быть хорошо спрятанными и на первый взгляд безобидными, вряд ли злоумышленники облегчат задачу и назовут свои изменения, например, "hacking_the_system" или "allowing_secret_remote_access". Вредоносный код может выглядеть совершенно безобидно или маскироваться под программный дефект.
#
# Поэтому тщательный анализ потребует большого количества ресурсов (человеческих, вычислительных, временныз), что стоит дорого.
#
# Логичным выходом является выделение критичных для целей безопасности проверок в отдельный блок, который протестировать должно быть гораздо проще.

# %% [markdown]
# #### Задания
#
# В этом модуле задание будет состоять из двух частей разной сложности:
#
# **3.1. добавить новый блок - "Ограничитель"** - этот модуль должен будет обеспечить соблюдение ограничений, указанных в маршрутном задании - это необходимо для обеспечения ЦБ1
#
# **З.2. *(задание повышенной сложности)* добавить монитор безопасности (МБ)** - он должен контролировать все взаимодействия *бортовых систем* (т.е. не включая планировщик и симулятор) и не давать блокам взаимодействовать друг с другом непредусмотренным образом - например, блок №5 может принимать команды только от №3, попытка передать команду в №5 от №2 должна блокироваться нашим монитором безопасности - потенциально это необходимо для обеспечения всех ЦБ

# %% [markdown]
# Для выполнения первой части задачи 3.1. необходимо для начала изменить архитектуру АНТС как показано на рис. 5
#
# ![Архитектура системы с ограничителем](images/ciac-arch-m31.png)
#
# Рис. 5. Архитектура АНТС с ограничителем (для ЦБ1)

# %% [markdown]
# Код базового класса Ограничителя находится в файле src/safety_block.py
#
# По аналогии с заданием в модуле 1, необходимо создать на основе этого класса свой собственный под названием SafetyBlock, в котором реализовать передачу команд в приводы движения, только перед эти необходимо ещё и проконтролировать их безопасность.
#
# Также необходимо реализовать передачу маршрутного задания из CommunicationGateway в SafetyBlock и координат из модуля Navigation в соответствии со стрелками на рис.5 выше.
#
# Если всё сделано правильно, то Ограничителю будет известно следующее
#
# - _mission - текущее маршрутное задание
# - _position - текущие координаты
#
# После проверки нужно установить значение внутренних переменных
# - _speed - текущая (допустимая) скорость
# - _direction - текущее (допустимое) направление
#
# Желательно завершить следование по маршруту. В критической ситуации, если продолжение маршрута невозможно, следует установить значение скорости и направления в 0, после чего передать эти команды в блок приводов (Servos)

# %% [markdown]
# Базовый сценарий для новой архитектуры можно представить следующим образом (см. рис. 6)
#
# ![Базовый сценарий с блоком безопасности](images/basic-scenario-with-safety-block1.png)
#
# Рис. 6. Базовый сценарий с блоком безопасности

# %% [markdown]
# Заготовка кода SafetyBlock
#
# ```python
# class SafetyBlock(BaseSafetyBlock):
#     """ класс ограничений безопасности """
#
#     def _set_new_direction(self, direction: float):
#         """ установка нового направления перемещения """
#         self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
#         self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
#         self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
#         # TODO реализовать контроль безопасности изменения направления
#         self._direction = direction
#         self._send_direction_to_consumers()
#
#     def _set_new_speed(self, speed: float):
#         """ установка новой скорости """
#         # TODO реализовать контроль безопасности изменения скорости
#         self._speed = speed
#         self._send_speed_to_consumers()
#
#     def _send_speed_to_consumers(self):
#         self._log_message(LOG_DEBUG, "отправляем скорость получателям")
#         servos_q_name = SERVOS_QUEUE_NAME
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)
#
#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(source=self.event_source_name,
#                             destination=servos_q_name,
#                             operation="set_speed",
#                             parameters=self._speed
#                             )
#         servos_q.put(event_speed)
#
#     def _send_direction_to_consumers(self):
#         self._log_message(LOG_DEBUG, "отправляем направление получателям")
#
#         servos_q_name = SERVOS_QUEUE_NAME
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)
#
#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(source=self.event_source_name,
#                             destination=servos_q_name,
#                             operation="set_direction",
#                             parameters=self._direction
#                             )
#         servos_q.put(event_speed)
# ```

# %%
# 1. скопируйте сюда код заготовки из предыдущей ячейки и напишите свою реализацию класса SafetyBlock
import math
from src.safety_block import BaseSafetyBlock
from src.config import LOG_ERROR, LOG_DEBUG, LOG_INFO, SERVOS_QUEUE_NAME

class SafetyBlock(BaseSafetyBlock):
    """ Класс ограничений безопасности """

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"новые координаты: {direction}")
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")

        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, "Неизвестный маршрут или позиция! Остановка.")
            self._stop_the_car()
            return
        
        target_point = self._route.next_point()
        current_point = self._position
        target_direction = self._calculate_bearing(current_point, target_point)
        tolerance = 1

        if (abs(target_direction - direction) > tolerance):
            self._log_message(LOG_ERROR, "Направление не совпадает с маршрутом! Остановка.")
            self._stop_the_car()
            return
        
        self._direction = direction    
        self._send_direction_to_consumers()

    def _calculate_bearing(self, start: GeoPoint, end: GeoPoint) -> float:
        delta_longitude = end.longitude - start.longitude
        x = math.sin(math.radians(delta_longitude)) * \
            math.cos(math.radians(end.latitude))
        y = math.cos(math.radians(start.latitude)) * math.sin(math.radians(end.latitude)) - \
            math.sin(math.radians(start.latitude)) * math.cos(math.radians(end.latitude)) * \
            math.cos(math.radians(delta_longitude))

        initial_bearing_rad = math.atan2(x, y)

        # Преобразуем радианы в градусы
        initial_bearing_deg = math.degrees(initial_bearing_rad)

        # Нормализуем значение в диапазоне [0, 360]
        compass_bearing = (initial_bearing_deg + 360) % 360

        return compass_bearing

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        self._log_message(LOG_INFO, f"новая скорость: {speed}")
        self._log_message(LOG_INFO, f"текущая скорость: {self._speed}")

        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, "Неизвестный маршрут или позиция! Остановка.")
            self._stop_the_car()
            return 
        
        allowed_speed = self._route.calculate_speed()
        
        if speed > allowed_speed:
            self._log_message(LOG_ERROR, f"Скорость {speed} превышает лимит {allowed_speed}. Ограничиваем.")
            self._speed = allowed_speed
        else:
            self._speed = speed
        
        self._send_speed_to_consumers()

    def _stop_the_car(self):
        self._speed = 0
        self._direction = 0    
        
        self._send_speed_to_consumers()  
        self._send_direction_to_consumers()

    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed)
        servos_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем направление получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        event_direction = Event(source=self.event_source_name,
                                destination=servos_q_name,
                                operation="set_direction",
                                parameters=self._direction)
        servos_q.put(event_direction)

# %%
from multiprocessing import Queue
from src.event_types import Event
from src.communication_gateway import BaseCommunicationGateway
from src.control_system import BaseControlSystem
from src.navigation_system import BaseNavigationSystem
from src.config import CONTROL_SYSTEM_QUEUE_NAME
from src.config import SAFETY_BLOCK_QUEUE_NAME

class CommunicationGateway(BaseCommunicationGateway):
    """Класс для реализации логики взаимодействия с системой планирования заданий.
    Работает в отдельном процессе, поэтому создаётся как наследник класса Process.
    """
    def _send_mission_to_consumers(self):
        """Метод для отправки сообщения с маршрутным заданием в систему управления."""
        
        # Получаем имя очереди системы управления
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME 

        # Создаём событие с маршрутным заданием
        event_control = Event(
            source=BaseCommunicationGateway.event_source_name,
            destination=control_q_name,
            operation="set_mission",
            parameters=self._mission
        )
        event_safety = Event(
            source=BaseCommunicationGateway.event_source_name,
            destination=safety_q_name,
            operation="set_mission",
            parameters=self._mission
        )

        # Ищем в каталоге нужную очередь
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        # Отправляем событие в найденную очередь
        control_q.put(event_control)
        safety_q.put(event_safety)
        
class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def _send_speed_and_direction_to_consumers(self, speed, direction):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(
            source=BaseControlSystem.event_source_name,
            destination=safety_q_name,
            operation="set_speed",
            parameters=speed
        )                   # замените на код создания сообщения со скоростью для приводов
                            # подсказка, требуемая операция - set_speed

        # отправка сообщения с желаемым направлением
        event_direction = Event(
            source=BaseControlSystem.event_source_name,
            destination=safety_q_name,
            operation="set_direction",
            parameters=direction
        )                       # замените на код создания сообщения с направлением для приводов
                                # подсказка, требуемая операция - set_direction

        safety_q.put(event_speed)
        safety_q.put(event_direction)       

class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):                              
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME # замените на правильное название очереди

        event_safety = Event(
            source=BaseNavigationSystem.event_source_name,
            destination=safety_q_name,
            operation="position_update",
            parameters=self._position           # Координаты текущего местоположения
        )                                       # замените на код создания сообщения с координатами для системы управления 
                                                # подсказка, требуемая операция - position_update

        event_control = Event(
            source=BaseNavigationSystem.event_source_name,
            destination=control_q_name,
            operation="position_update",
            parameters=self._position          
        )     
                                                
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        
        safety_q.put(event_safety)
        control_q.put(event_control)

communication_gateway = CommunicationGateway(queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)
navigation_system = NavigationSystem(queues_dir=queues_dir, log_level=LOG_ERROR)
# Out:
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation

# %%
# создадим все остальные компоненты

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)
# Out:
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель

# %%
# соберём все компоненты для запуска
# в зависимости от наличия СУПА используем разный набор компонентов - с передачей телеметрии или без

system_components = SystemComponentsContainer(
components=[
        # вариант компонентов с передачей телеметрии в СУПА
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ] if afcs_present else [
        # вариант компонентов для конфигурации без СУПА
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ])

system_components.start()

# настройте этот параметр так, чтобы проверить работу ограничителя
sleep(180)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека[ИНФО][CONTROL] старт системы управления
#
# [ИНФО][SAFETY] старт ограничителя
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 20:19:19.166794
# [ИНФО][SAFETY] Блокировка грузового отсека
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][CONTROL] новая скорость 20 (была 0)
# [ИНФО][CONTROL] новое направление 253 (было 0)
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 0
# [ИНФО][SAFETY] новые координаты: 253.75928369921178
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.5808s N, 29 49m 38.514s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.75928369921178
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.5808s N, 29 49m 38.514s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.75928369921178
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.5808s N, 29 49m 38.514s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.75928369921178
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.5808s N, 29 49m 38.514s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7596574932637
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.5557s N, 29 49m 38.3426s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.75996567168647
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.53561s N, 29 49m 38.2055s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76036284781054
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.51051s N, 29 49m 38.0341s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7607676970021
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.48541s N, 29 49m 37.8627s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76118171945132
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.46031s N, 29 49m 37.6914s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.761603855511
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.43521s N, 29 49m 37.52s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76203439667435
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.4101s N, 29 49m 37.3486s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76247362837023
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.385s N, 29 49m 37.1772s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76292187562893
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.3599s N, 29 49m 37.0058s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76337948301693
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.33481s N, 29 49m 36.8344s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76384681765887
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.30971s N, 29 49m 36.663s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76432426356297
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.28461s N, 29 49m 36.4916s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76481223154846
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.25951s N, 29 49m 36.3203s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7653111571264
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.23442s N, 29 49m 36.1489s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76582150299
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.20932s N, 29 49m 35.9775s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7663437637417
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.18423s N, 29 49m 35.8061s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76687846428348
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.15913s N, 29 49m 35.6347s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76742616652706
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.13404s N, 29 49m 35.4633s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76798746901278
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.10895s N, 29 49m 35.2919s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7685630167648
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.08386s N, 29 49m 35.1205s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76915349671745
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.05876s N, 29 49m 34.9491s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76975965022214
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.03367s N, 29 49m 34.7778s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77038227375544
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.00859s N, 29 49m 34.6064s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77102222706344
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.9835s N, 29 49m 34.435s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7716804371865
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.95841s N, 29 49m 34.2636s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.772357907717
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.93332s N, 29 49m 34.0922s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7730557291517
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.90824s N, 29 49m 33.9208s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77377508663847
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.88315s N, 29 49m 33.7494s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77451726959
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.85807s N, 29 49m 33.578s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7752836894905
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.83299s N, 29 49m 33.4066s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77607588865442
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.80791s N, 29 49m 33.2352s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77689556700432
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.78283s N, 29 49m 33.0638s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77774459041416
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.75775s N, 29 49m 32.8924s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77862502594013
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.73267s N, 29 49m 32.721s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77953916717516
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.70759s N, 29 49m 32.5496s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.78048956286557
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.68252s N, 29 49m 32.3782s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.78147906633336
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.65744s N, 29 49m 32.2068s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.78251087908038
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.63237s N, 29 49m 32.0354s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.78358860740502
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.6073s N, 29 49m 31.864s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7847163418953
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.58223s N, 29 49m 31.6926s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.78589873991166
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.55716s N, 29 49m 31.5212s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7871411369478
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.5321s N, 29 49m 31.3498s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7884496901146
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.50703s N, 29 49m 31.1784s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7898315402299
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.48197s N, 29 49m 31.007s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.79129505605067
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.45691s N, 29 49m 30.8356s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.79285010393062
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.43185s N, 29 49m 30.6642s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7945084354808
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.40679s N, 29 49m 30.4928s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.79628420962098
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.38174s N, 29 49m 30.3214s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.79819468260342
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.35668s N, 29 49m 30.1499s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.80026115886568
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.33163s N, 29 49m 29.9785s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.80251035345253
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.30658s N, 29 49m 29.8071s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.80497639079942
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.28154s N, 29 49m 29.6357s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.8077037574387
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.2565s N, 29 49m 29.4643s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.81075188634196
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.23146s N, 29 49m 29.2929s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.8142025596357
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.20643s N, 29 49m 29.1214s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.81730160538638
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.1864s N, 29 49m 28.9843s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.82171666315594
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.16138s N, 29 49m 28.8129s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.8269897443671
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.13636s N, 29 49m 28.6414s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.83367174114323
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.11134s N, 29 49m 28.47s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.84243729136077
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.08633s N, 29 49m 28.2986s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.85491435820353
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.06133s N, 29 49m 28.1271s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.87530907270582
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.03634s N, 29 49m 27.9557s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 303 (было 253)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 303.80923567429636
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.01136s N, 29 49m 27.7842s E
# [ИНФО][CONTROL] новое направление 305 (было 303)
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 305.95547796372705
# [ИНФО][SAFETY] текущие координаты: 59 52m 7.9864s N, 29 49m 27.6128s E
# [ИНФО][CONTROL] новое направление 308 (было 305)
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 308.23384527292416
# [ИНФО][SAFETY] текущие координаты: 59 52m 7.96147s N, 29 49m 27.4413s E
# [ИНФО][CONTROL] новое направление 310 (было 308)
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 310.64977597229307
# [ИНФО][SAFETY] текущие координаты: 59 52m 7.93654s N, 29 49m 27.2698s E
# [ИНФО][CONTROL] новое направление 311 (было 310)
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.02052333839174
# [ИНФО][SAFETY] текущие координаты: 59 52m 7.98649s N, 29 49m 27.1215s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.31042896659045
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.03919s N, 29 49m 26.977s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.4962912213404
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.09474s N, 29 49m 26.8368s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.5484871107494
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.15321s N, 29 49m 26.7013s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.58203771837304
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.21212s N, 29 49m 26.5667s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.5988178569468
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.27138s N, 29 49m 26.4326s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.60320204672735
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.33085s N, 29 49m 26.2989s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.6037405267014
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.39038s N, 29 49m 26.1653s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.6011246476541
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.44995s N, 29 49m 26.0318s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.5956694329816
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.50955s N, 29 49m 25.8983s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.58883648872944
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.56915s N, 29 49m 25.7648s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.5804915614003
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.62874s N, 29 49m 25.6313s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.5703648732768
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.68833s N, 29 49m 25.4978s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.5577060134304
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.74791s N, 29 49m 25.3643s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.5410956548331
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.80748s N, 29 49m 25.2308s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.5174692665395
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.86704s N, 29 49m 25.0972s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.47873002235207
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.92658s N, 29 49m 24.9637s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 60 (была 20)
# [ИНФО][CONTROL] новое направление 60 (было 311)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 60.17505663413817
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.9861s N, 29 49m 24.83s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 60.683778496415584
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.0456s N, 29 49m 24.6964s E
# [ИНФО][CONTROL] новое направление 61 (было 60)
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.189265645385206
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.10505s N, 29 49m 24.5626s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.21981388730114
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.23898s N, 29 49m 25.0272s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.23706493991051
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.37082s N, 29 49m 25.4942s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.239896669192206
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.50059s N, 29 49m 25.9634s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.24193901662068
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.63023s N, 29 49m 26.4328s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.24354834133726
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.7598s N, 29 49m 26.9022s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.24516680950387
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.88936s N, 29 49m 27.3717s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.24682290344509
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.0189s N, 29 49m 27.8412s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.24853634422391
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.1485s N, 29 49m 28.3107s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.25031323212784
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.278s N, 29 49m 28.7801s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.252159506751184
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.4075s N, 29 49m 29.2496s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.25408127221999
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.5371s N, 29 49m 29.7191s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.25608540464009
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.6666s N, 29 49m 30.1887s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.25817972836637
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.7961s N, 29 49m 30.6582s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.26037323000054
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.9256s N, 29 49m 31.1277s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.262676300495855
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.0551s N, 29 49m 31.5973s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.26510104110747
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.1846s N, 29 49m 32.0668s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.2676616606235
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.314s N, 29 49m 32.5364s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.270374994370286
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.4435s N, 29 49m 33.0059s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.27326117874867
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.573s N, 29 49m 33.4755s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.27634458083685
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.7024s N, 29 49m 33.9451s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.279655046911046
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.8318s N, 29 49m 34.4147s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.28322966802483
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.9613s N, 29 49m 34.8843s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.28711529371907
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.0907s N, 29 49m 35.354s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.29137223697791
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.2201s N, 29 49m 35.8236s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.29607988553283
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.3495s N, 29 49m 36.2933s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.301345527824196
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.4788s N, 29 49m 36.763s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.307318829989526
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.6082s N, 29 49m 37.2327s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.31269872991584
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.7116s N, 29 49m 37.6085s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.32039918018438
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.8409s N, 29 49m 38.0782s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.32967711986754
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.9702s N, 29 49m 38.548s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.34161928630681
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.0995s N, 29 49m 39.0178s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.35767904889053
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.2287s N, 29 49m 39.4876s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.38156986083595
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.3579s N, 29 49m 39.9575s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.42424556840291
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.487s N, 29 49m 40.4275s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.543659641920556
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.6161s N, 29 49m 40.8975s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 90 (было 61)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] новая скорость: 60[ИНФО][SAFETY] текущая скорость: 60
#
# [ИНФО][SAFETY] новые координаты: 90.38658840131234
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7451s N, 29 49m 41.3676s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 90.88609398827373
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.8739s N, 29 49m 41.8379s E
# [ИНФО][CONTROL] новое направление 91 (было 90)
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.39958268981064
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0022s N, 29 49m 42.3087s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.92958862163141
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.1305s N, 29 49m 42.7796s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.95886143552912
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.1287s N, 29 49m 43.3151s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.97962412214156
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.1245s N, 29 49m 43.8506s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99109886168145
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.1179s N, 29 49m 44.386s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99180771949506
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.1087s N, 29 49m 44.9212s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99211776053244
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0994s N, 29 49m 45.4564s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.9921981790801
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0901s N, 29 49m 45.9916s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99226415141527
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0807s N, 29 49m 46.5269s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99232343316686
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0714s N, 29 49m 47.0621s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99238069747071
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.062s N, 29 49m 47.5973s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99243613751696
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0526s N, 29 49m 48.1325s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99248978066441
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0433s N, 29 49m 48.6677s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99254154811456
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0339s N, 29 49m 49.203s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99259134578972
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0246s N, 29 49m 49.7382s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99263907085663
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0152s N, 29 49m 50.2734s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99268461173017
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0058s N, 29 49m 50.8086s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99272784866321
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9965s N, 29 49m 51.3438s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99276864880164
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9871s N, 29 49m 51.8791s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99280687081477
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9777s N, 29 49m 52.4143s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99284236004797
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9684s N, 29 49m 52.9495s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99287494520047
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.959s N, 29 49m 53.4847s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99290444052451
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9496s N, 29 49m 54.0199s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99293064166653
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9403s N, 29 49m 54.5552s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.9929533226491
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9309s N, 29 49m 55.0904s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99297223446257
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9216s N, 29 49m 55.6256s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99298709973516
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9122s N, 29 49m 56.1608s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99299761018437
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9028s N, 29 49m 56.696s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.9930034209699
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.8935s N, 29 49m 57.2313s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99300414251297
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.8841s N, 29 49m 57.7665s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.9929993396392
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.8747s N, 29 49m 58.3017s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99298851542403
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.8654s N, 29 49m 58.8369s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99297110442905
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.856s N, 29 49m 59.3721s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99294645728969
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.8466s N, 29 49m 59.9074s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99291382428146
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.8373s N, 29 50m 0.442574s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.992872333062
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.8279s N, 29 50m 0.977793s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.9928209620652
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.8185s N, 29 50m 1.51301s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99275850636047
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.8092s N, 29 50m 2.04823s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99268352027934
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7998s N, 29 50m 2.58345s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99259426649411
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7904s N, 29 50m 3.11867s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99248862086858
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7811s N, 29 50m 3.65389s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99236395103077
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7717s N, 29 50m 4.18911s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99221694177419
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7624s N, 29 50m 4.72432s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99208120952932
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7549s N, 29 50m 5.1525s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99188489628494
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7455s N, 29 50m 5.68772s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.9916516195982
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7361s N, 29 50m 6.22294s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99136797457794
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7268s N, 29 50m 6.75816s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99102282529492
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7174s N, 29 50m 7.29338s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.9905954467963
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7081s N, 29 50m 7.82859s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.99005375363362
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.6987s N, 29 50m 8.36381s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.9893427641938
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.6894s N, 29 50m 8.89903s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98835911830383
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.68s N, 29 50m 9.43425s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98687709564297
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.6707s N, 29 50m 9.96947s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98427049286875
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.6613s N, 29 50m 10.5047s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.97776270829132
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.652s N, 29 50m 11.0399s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 96 (было 91)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 96.93149765223046
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.6426s N, 29 50m 11.5751s E
# [ИНФО][CONTROL] новое направление 97 (было 96)
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.02355166910382
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.6333s N, 29 50m 12.1104s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.11920518083468
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.624s N, 29 50m 12.6456s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.12273797359785
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.5915s N, 29 50m 13.1772s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.1245895263612
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.5586s N, 29 50m 13.7087s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.12458586934406
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.5252s N, 29 50m 14.2401s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.12450680584567
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.4918s N, 29 50m 14.7715s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.12438288627743
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.4584s N, 29 50m 15.303s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.12425100739961
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.425s N, 29 50m 15.8344s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.1241105659314
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.3916s N, 29 50m 16.3658s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.12396275955655
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.3582s N, 29 50m 16.8972s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.12380810996888
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.3248s N, 29 50m 17.4286s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.12364632350182
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.2914s N, 29 50m 17.96s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.123477092146
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.258s N, 29 50m 18.4914s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.12330004821706
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.2247s N, 29 50m 19.0228s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.12311477516391
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.1913s N, 29 50m 19.5542s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.12292082011788
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.1579s N, 29 50m 20.0856s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.12271768893993
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.1245s N, 29 50m 20.617s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.12250484562225
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.0911s N, 29 50m 21.1484s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.12228170562287
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.0577s N, 29 50m 21.6798s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.12204762932896
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.0243s N, 29 50m 22.2112s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.12180823913968
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.9909s N, 29 50m 22.7426s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.12155714442127
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.9575s N, 29 50m 23.274s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.12129358390439
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.9241s N, 29 50m 23.8055s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.12101651260741
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.8908s N, 29 50m 24.3369s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.12072496160295
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.8574s N, 29 50m 24.8683s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.12041785311322
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.824s N, 29 50m 25.3997s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.12009399041824
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.7906s N, 29 50m 25.9311s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.11975203714582
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.7572s N, 29 50m 26.4625s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.11939048729408
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.7238s N, 29 50m 26.9939s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.11900764128018
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.6905s N, 29 50m 27.5253s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.11860157007459
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.6571s N, 29 50m 28.0567s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.11817007171055
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.6237s N, 29 50m 28.5881s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.11771061475315
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.5904s N, 29 50m 29.1195s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.11722027306541
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.557s N, 29 50m 29.6509s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.11669563998146
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.5236s N, 29 50m 30.1823s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.11613271641522
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.4903s N, 29 50m 30.7138s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.11552676313755
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.4569s N, 29 50m 31.2452s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.11487211365909
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.4235s N, 29 50m 31.7766s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.11416191485955
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.3902s N, 29 50m 32.308s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.11338776900527
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.3568s N, 29 50m 32.8394s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.11253925238918
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.3235s N, 29 50m 33.3708s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.11160319163304
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.2901s N, 29 50m 33.9022s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.11056264310389
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.2568s N, 29 50m 34.4336s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.10939530868785
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.2234s N, 29 50m 34.9651s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.10835831266263
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.1968s N, 29 50m 35.3902s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.10690441773318
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.1634s N, 29 50m 35.9216s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.10521482306211
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.1301s N, 29 50m 36.453s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.10316843965768
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.0968s N, 29 50m 36.9844s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.10065496257931
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.0635s N, 29 50m 37.5159s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.09743745309243
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.0302s N, 29 50m 38.0473s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.09306802442234
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.9969s N, 29 50m 38.5787s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.08652263530337
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.9636s N, 29 50m 39.1101s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.07476508985792
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.9303s N, 29 50m 39.6416s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.04201490689525
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.897s N, 29 50m 40.173s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 113 (было 97)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 113.53871105501065
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.8638s N, 29 50m 40.7044s E
# [ИНФО][CONTROL] новое направление 114 (было 113)
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 114.20397488281282
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.8307s N, 29 50m 41.2359s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 114.92480555448554
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.7976s N, 29 50m 41.7674s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# ...
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.2386s N, 29 50m 44.2032s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 115.01922801345694
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.1247s N, 29 50m 44.6884s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 115.01684549354155
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.0108s N, 29 50m 45.1737s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 115.01425921616692
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.8969s N, 29 50m 45.659s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 115.01145286732037
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.783s N, 29 50m 46.1443s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 115.00839764126442
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.6692s N, 29 50m 46.6295s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 115.00504990810828
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.5553s N, 29 50m 47.1148s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 115.00135220516427
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.4415s N, 29 50m 47.6001s E
# [ИНФО][CONTROL] новое направление 114 (было 115)
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 114.99722781202172
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.3276s N, 29 50m 48.0855s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 114.99257211499798
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.2138s N, 29 50m 48.5708s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 114.98679897918032
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.1s N, 29 50m 49.0561s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 114.97995539550107
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.98616s N, 29 50m 49.5415s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 114.97160884952007
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.87237s N, 29 50m 50.0268s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 114.96102790261682
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.7586s N, 29 50m 50.5122s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 114.94695398323688
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.64486s N, 29 50m 50.9976s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 114.92665022436285
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.53115s N, 29 50m 51.483s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 114.8930656507286
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.41747s N, 29 50m 51.9685s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 114.82003510258465
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.30383s N, 29 50m 52.454s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 42 (было 114)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 42.87423586016297
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.19034s N, 29 50m 52.9396s E
# [ИНФО][CONTROL] новое направление 39 (было 42)
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 39.889105368688604
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.077s N, 29 50m 53.4254s E
# [ИНФО][CONTROL] новое направление 36 (было 39)
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.81940733149963
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.96396s N, 29 50m 53.9115s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.46742626978221
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.1613s N, 29 50m 54.2758s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.257152055190545
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.36791s N, 29 50m 54.6193s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.22292051150413
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.58348s N, 29 50m 54.9402s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.20888087089884
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.80003s N, 29 50m 55.2585s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.20881186299084
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.0172s N, 29 50m 55.5752s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.21156957735877
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.2344s N, 29 50m 55.8917s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.216092972435035
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.4517s N, 29 50m 56.208s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.221517829698655
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.6689s N, 29 50m 56.5244s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.227830764169255
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.8862s N, 29 50m 56.8408s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.23514381962593
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.1034s N, 29 50m 57.1572s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.24375572303671
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.3207s N, 29 50m 57.4736s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.254165650243124
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.5379s N, 29 50m 57.7901s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.26724765009476
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.7551s N, 29 50m 58.1067s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.284669666436
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.9723s N, 29 50m 58.4233s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.31013842117994
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.1894s N, 29 50m 58.74s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.35424189735801
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.4065s N, 29 50m 59.0568s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.46715535483571
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.6236s N, 29 50m 59.3737s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 20 (была 60)
# [ИНФО][CONTROL] новое направление 345 (было 36)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 345.0981436017722
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.8406s N, 29 50m 59.6908s E
# [ИНФО][CONTROL] новое направление 339 (было 345)
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 339.6615856522152
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.0141s N, 29 50m 59.9448s E
# [ИНФО][CONTROL] новое направление 331 (было 339)
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 331.76926015294896
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.2306s N, 29 51m 0.263102s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 331.00401811883484
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.3174s N, 29 51m 0.217195s E
# [ИНФО][CONTROL] новое направление 330 (было 331)
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 330.47316430143604
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.4015s N, 29 51m 0.15515s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 330.38584711425
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.4806s N, 29 51m 0.0707085s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 330.33974905319036
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.5591s N, 29 50m 59.9842s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 330.3265731460373
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.6372s N, 29 50m 59.8962s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 330.3183451848574
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7152s N, 29 50m 59.808s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 330.31273638294414
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7932s N, 29 50m 59.7196s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 330.30731847005876
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.8712s N, 29 50m 59.6313s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 330.30162196605283
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9492s N, 29 50m 59.5429s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 330.29523139368644
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0272s N, 29 50m 59.4545s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 330.28783583692876
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.1052s N, 29 50m 59.366s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 330.2790016117766
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.1831s N, 29 50m 59.2776s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 330.268046541922
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.2611s N, 29 50m 59.1891s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 330.2537274292838
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.339s N, 29 50m 59.1007s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 330.2334297131049
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.417s N, 29 50m 59.0121s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 330.200306881952
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.4949s N, 29 50m 58.9236s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 334 (было 330)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 334.4666214252246
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.5729s N, 29 50m 58.835s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 334.77345895784737
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.6508s N, 29 50m 58.7464s E
# [ИНФО][CONTROL] новое направление 335 (было 334)
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 335.1312668992742
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.7287s N, 29 50m 58.6577s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 335.1850598708135
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.8097s N, 29 50m 58.5808s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 335.22017561556675
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.8909s N, 29 50m 58.5047s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 335.22552956573264
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.9723s N, 29 50m 58.4296s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 335.2259107561538
# [ИНФО][SAFETY] текущие координаты: 59 52m 15.0538s N, 29 50m 58.3547s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 335.2218079297286
# [ИНФО][SAFETY] текущие координаты: 59 52m 15.1353s N, 29 50m 58.2799s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 335.21566923464854
# [ИНФО][SAFETY] текущие координаты: 59 52m 15.2168s N, 29 50m 58.205s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 335.2072928010737
# [ИНФО][SAFETY] текущие координаты: 59 52m 15.2983s N, 29 50m 58.1302s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 335.1961980156985
# [ИНФО][SAFETY] текущие координаты: 59 52m 15.3798s N, 29 50m 58.0554s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 335.1807071543141
# [ИНФО][SAFETY] текущие координаты: 59 52m 15.4612s N, 29 50m 57.9806s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 335.15668484919064
# [ИНФО][SAFETY] текущие координаты: 59 52m 15.5427s N, 29 50m 57.9057s E
# [ИНФО][CONTROL] маршрут пройден, текущее время 20:21:56.770344
# [ИНФО][CONTROL] новая скорость 0.0 (была 20)
# [ИНФО][CONTROL] новое направление 0 (было 335)
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] новая скорость: 0.0
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 0.0
# [ИНФО][SAFETY] текущие координаты: 59 52m 15.6242s N, 29 50m 57.8308s E
# [ОШИБКА][SAFETY] ошибка обработки команд: 'NoneType' object has no attribute 'longitude'
# [ИНФО][CARGO] выгрузка
# [ИНФО][CARGO] груз оставлен
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден

# %% [markdown]
# #### Обеспечение ЦБ3: контроль доставки груза
#
# С помощью логики ограничителя выше мы реализовали обеспечение ЦБ1 (соблюдение заданных ограничений), однако есть ещё ЦБ3 (отгрузка только в заданной точке), не говоря о ЦБ2 (следование только по аутентичному маршруту).
#
# Для обеспечения ЦБ3 необходимо сделать следующее
# 1. изменить последовательность передачи команд, чтобы в блок управления грузовым отсеком (CargoBay) команды приходили только после проверки в Ограничителе
# 2. доработайте реализацию Ограничителя, чтобы команда на выгрузку передавалась в CargoBay только в конечной точке маршрута
# 3. продумайте логику работы блока безопасности, если система управления полностью перестанет работать (т.е. перестанет отправлять новые команды).
#
# Изменённая архитектура приведена на рис. 7.
#
# ![Ограничитель для обеспечения ЦБ1 и ЦБ3](images/ciac-arch-m312.png)
#
# Рис. 7. Ограничитель для обеспечения ЦБ1 и ЦБ3

# %%
# напишите свой код в этой ячейке, запустите машинку по маршруту, убедитесь, 
# что в конечной (и только в конечной!) точке CargoBay получает команду и успешно выполняет выгрузку

import math
from multiprocessing import Queue
from src.event_types import Event
from src.communication_gateway import BaseCommunicationGateway
from src.control_system import BaseControlSystem
from src.navigation_system import BaseNavigationSystem
from src.safety_block import BaseSafetyBlock
from src.config import LOG_ERROR, LOG_DEBUG, LOG_INFO, SERVOS_QUEUE_NAME, CARGO_BAY_QUEUE_NAME, CONTROL_SYSTEM_QUEUE_NAME, SAFETY_BLOCK_QUEUE_NAME

class CommunicationGateway(BaseCommunicationGateway):
    """Класс для реализации логики взаимодействия с системой планирования заданий.
    Работает в отдельном процессе, поэтому создаётся как наследник класса Process.
    """
    def _send_mission_to_consumers(self):
        """Метод для отправки сообщения с маршрутным заданием в систему управления."""
        
        # Получаем имя очереди системы управления
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME 

        # Создаём событие с маршрутным заданием
        event_control = Event(
            source=BaseCommunicationGateway.event_source_name,
            destination=control_q_name,
            operation="set_mission",
            parameters=self._mission
        )
        event_safety = Event(
            source=BaseCommunicationGateway.event_source_name,
            destination=safety_q_name,
            operation="set_mission",
            parameters=self._mission
        )

        # Ищем в каталоге нужную очередь
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        # Отправляем событие в найденную очередь
        control_q.put(event_control)
        safety_q.put(event_safety)
        
class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def _send_speed_and_direction_to_consumers(self, speed, direction):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(
            source=BaseControlSystem.event_source_name,
            destination=safety_q_name,
            operation="set_speed",
            parameters=speed
        )                   # замените на код создания сообщения со скоростью для приводов
                            # подсказка, требуемая операция - set_speed

        # отправка сообщения с желаемым направлением
        event_direction = Event(
            source=BaseControlSystem.event_source_name,
            destination=safety_q_name,
            operation="set_direction",
            parameters=direction
        )                       # замените на код создания сообщения с направлением для приводов
                                # подсказка, требуемая операция - set_direction

        safety_q.put(event_speed)
        safety_q.put(event_direction)   

    
    def _release_cargo(self):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME 
        
        event_release_cargo = Event(
            source=BaseControlSystem.event_source_name,
            destination=safety_q_name,
            operation="release_cargo",
            parameters=None
        )                      

        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event_release_cargo)   


    def _lock_cargo(self):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME 
        
        event_lock_cargo = Event(
            source=BaseControlSystem.event_source_name,
            destination=safety_q_name,
            operation="lock_cargo",
            parameters=None
        )                      

        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event_lock_cargo)    

class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):                              
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME # замените на правильное название очереди

        event_safety = Event(
            source=BaseNavigationSystem.event_source_name,
            destination=safety_q_name,
            operation="position_update",
            parameters=self._position           # Координаты текущего местоположения
        )                                       # замените на код создания сообщения с координатами для системы управления 
                                                # подсказка, требуемая операция - position_update

        event_control = Event(
            source=BaseNavigationSystem.event_source_name,
            destination=control_q_name,
            operation="position_update",
            parameters=self._position          
        )     
                                                
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        
        safety_q.put(event_safety)
        control_q.put(event_control)

class SafetyBlock(BaseSafetyBlock):
    """ Класс ограничений безопасности """

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"новые координаты: {direction}")
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")

        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, "Неизвестный маршрут или позиция! Остановка.")
            self._stop_the_car()
            return
        
        target_direction = self._calculate_bearing(self._position, self._route.next_point())
        tolerance = 1

        if (abs(target_direction - direction) > tolerance):
            self._log_message(LOG_ERROR, "Направление не совпадает с маршрутом! Остановка.")
            self._stop_the_car()
            return
        
        self._direction = direction    
        self._send_direction_to_consumers()

    def _calculate_bearing(self, start: GeoPoint, end: GeoPoint) -> float:
        delta_longitude = end.longitude - start.longitude
        x = math.sin(math.radians(delta_longitude)) * \
            math.cos(math.radians(end.latitude))
        y = math.cos(math.radians(start.latitude)) * math.sin(math.radians(end.latitude)) - \
            math.sin(math.radians(start.latitude)) * math.cos(math.radians(end.latitude)) * \
            math.cos(math.radians(delta_longitude))

        initial_bearing_rad = math.atan2(x, y)

        # Преобразуем радианы в градусы
        initial_bearing_deg = math.degrees(initial_bearing_rad)

        # Нормализуем значение в диапазоне [0, 360]
        compass_bearing = (initial_bearing_deg + 360) % 360

        return compass_bearing

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        self._log_message(LOG_INFO, f"новая скорость: {speed}")
        self._log_message(LOG_INFO, f"текущая скорость: {self._speed}")

        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, "Неизвестный маршрут или позиция! Остановка.")
            self._stop_the_car()
            return 
        
        allowed_speed = self._route.calculate_speed()
        
        if speed > allowed_speed:
            self._log_message(LOG_ERROR, f"Скорость {speed} превышает лимит {allowed_speed}. Ограничиваем.")
            self._speed = allowed_speed
        else:
            self._speed = speed
        
        self._send_speed_to_consumers()

    def _stop_the_car(self):
        self._speed = 0
        self._direction = 0    
        
        self._send_speed_to_consumers()  
        self._send_direction_to_consumers()
        self._send_lock_cargo_to_consumers()

    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed)
        servos_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем направление получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        event_direction = Event(source=self.event_source_name,
                                destination=servos_q_name,
                                operation="set_direction",
                                parameters=self._direction)
        servos_q.put(event_direction)

    def _lock_cargo(self, _):
        self._log_message(LOG_INFO, "Блокировка грузового отсека")
        self._send_lock_cargo_to_consumers()

    def _release_cargo(self, _):
        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, "Неизвестный маршрут или позиция! Остановка.")
            self._stop_the_car()
            return 

        if not self._route.route_finished:
            self._log_message(LOG_INFO, "Маршрут не завершён, выгрузка невозможна!")
            return
        
        self._send_release_cargo_to_consumers()
    

    def _send_lock_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду на блокировку грузового отсека")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="lock_cargo",
            parameters=None
        )
        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        cargo_q.put(event)

    def _send_release_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду на разблокировку грузового отсека")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="release_cargo",
            parameters=None
        )
        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        cargo_q.put(event)

communication_gateway = CommunicationGateway(queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)
navigation_system = NavigationSystem(queues_dir=queues_dir, log_level=LOG_ERROR)
# Out:
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation

# %% [markdown]
# Выполнено!)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### *Опциональное задание повышенной сложности* Обеспечение ЦБ2
#
# **Перед началом работы над этой задачей рекомендуем сохранить все текущие изменения в git репозитории (git commit, git push).**
#
# Напомним цель безопасности №2 (ЦБ2): "При любых обстоятельствах АНТС выполняет только аутентичный (подлинный) маршрут"
#
# Обеспечение ЦБ2 потребует
# - внедрения механизма **контроля аутентичности маршрутного задания** (mission), а значит
# - помимо изменения **блока безопасности** (SafetyBlock), модификации
#   - системы **планирования задания** (MissionPlanner)
#   - **коммуникационного шлюза** (CommunicationGateway)
#   - и, возможно, **системы управления** (ControlSystem).
#
# Для решения этой задачи допустимо менять код соответствующих модулей в папке src.
#
# Возможным решением является внедрение механизма цифровой подписи, верификацией которой будет заниматься блок безопасности. В этой ситуации если коммуникационный шлюз (блок "1. Связь" на рис. 5 в модуле 1) оказался скомпрометированным и изменил маршрутное задание, оно не должно пройти проверку подлинности в блоке безопасности.
#
# **Рекомендуем эту задачу делать в последнюю очередь**, *после успешного выполнения модуля 4*, поскольку успешное выполнение модуля 4 принесёт больше баллов, чем внедрение цифровой подписи и обеспечение ЦБ2.
# К сведению, реализованные в этой версии киберпрепятствия не предполагают компрометацию маршрутного задания.
#
# Конечно, если будут решены все основные задачи и к тому же обеспечен контроль аутентичности маршрутного задания, такая работа с высокой вероятностью окажется лучшей.

# %%
# если вы собираетесь выполнить это задание, напишите в этой ячейке код выполнения изменённых блоков. 
# cам код допускается редактировать в папке src
# в случае успешной реализации машинка должна успешно пройти по маршруту, а в случае искажения маршрутного задания в блоке коммуникационного шлюза должна остаться на месте, 
# при этом именно блок безопасности должен заблокировать движение

# %% [markdown]
# ### Задание 3.2. Монитор безопасности

# %% [markdown]
# В текущей реализации каждый блок сам решает куда и какие данные ему отправлять. Это приемлемо, когда каждый блок рассматривается как благонадёжный. Однако нельзя исключать ситуацию успешной компрометации какого-либо из блоков (одного или нескольких), в результате которой злоумышленник может получить полный контроль над частью системы.
#
# В такой ситуации необходимо выстроить внутреннюю "поверхность защиты", частью этой системы уже является блок "Ограничитель", однако необходимо сделать так, чтобы соответствующие запросы проходили только через него, а не в обход.
#
# Для решения этой задачи необходимо добавить новый блок "Монитор безопасности". Его задача - обеспечить контроль направления информационных потоков, допустить передачу данных только между теми блоками и в тех направлениях, которые задуманы архитектором системы. Тогда, например, попытка передать команду из системы управления напрямую в сервоприводы в обход ограничителя будет заблокирована.
#
# Возможно, возникнет вопрос, а что помешает злоумышленнику отправить команду в обход этого монитора безопасности. В рамках этой учебной инфраструктуры особо ничего, однако при разработке реальной системы можно использовать специализированные микроядерные операционные системы, такие как, например, KasperskyOS, которые обеспечат обязательное вовлечение монитора безопасности в контроль взаимодействия между блоками.
#
# Архитектура системы для решения задачи 3.2 должна выглядеть как на рис.8:
#
# ![Архитектура системы с монитором безопасности](images/ciac-arch-m32.png)
#
# Рис. 8. Архитектура бортовых систем с монитором безопасности

# %% [markdown]
# Базовый класс модуля безопасности находится в файле src/security_monitor.py, его менять не нужно.
#
# В следующей ячейке находится реализация класса SecurityMonitor

# %%
from src.security_monitory import BaseSecurityMonitor
from src.security_policy_type import SecurityPolicy

from src.config import COMMUNICATION_GATEWAY_QUEUE_NAME, LOG_DEBUG, LOG_ERROR, LOG_INFO
    
    
class SecurityMonitor(BaseSecurityMonitor):
    """ класс монитора безопасности """

    def __init__(self, queues_dir):
        super().__init__(queues_dir)
        self._init_set_security_policies()

    def _init_set_security_policies(self):
        """ инициализация политик безопасности """
        default_policies = [
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='set_mission')
        ]
        self.set_security_policies(policies=default_policies)        

    def set_security_policies(self, policies):
        """ установка новых политик безопасности """
        self._security_policies = policies
        self._log_message(
            LOG_INFO, f"изменение политик безопасности: {policies}")

    def _check_event(self, event: Event):
        """ проверка входящих событий """
        self._log_message(
            LOG_DEBUG, f"проверка события {event}, по умолчанию выполнение запрещено")

        authorized = False
        request = SecurityPolicy(
            source=event.source,
            destination=event.destination,
            operation=event.operation)

        if request in self._security_policies:
            self._log_message(
                LOG_DEBUG, "событие разрешено политиками, выполняем")
            authorized = True

        if authorized is False:
            self._log_message(LOG_ERROR, f"событие не разрешено политиками безопасности! {event}")
        return authorized

# %% [markdown]
# Обратите внимание на этот код:
# ```python
#     def _init_set_security_policies(self):
#         """ инициализация политик безопасности """
#         default_policies = [
#             SecurityPolicy(
#                 source=COMMUNICATION_GATEWAY_QUEUE_NAME,
#                 destination=CONTROL_SYSTEM_QUEUE_NAME,
#                 operation='set_mission')
#         ]
#         self.set_security_policies(policies=default_policies)
# ```
#
# В нём инициализируется политика безопасности, разрешающая запрос set_mission от коммуникационного шлюза в систему управления.
#
# Код политики безопасности в строка 6-9:
# ```python
# SecurityPolicy(
#                 source=COMMUNICATION_GATEWAY_QUEUE_NAME,
#                 destination=CONTROL_SYSTEM_QUEUE_NAME,
#                 operation='set_mission')
# ```
#
# Шаблон политики безопасности описан в файле src/security_policy_type.py:
# ```python
# @dataclass
# class SecurityPolicy:
#     """ политика безопасности """
#     source: str         # отправитель запроса
#     destination: str    # получатель
#     operation: str      # запрашиваемая операция
#
# ```
#
# По аналогии в методе _init_set_security_policies допишите другие политики безопасности, чтобы разрешить взаимодействия согласно диаграмме на рис.7. выше.

# %% [markdown]
# Теперь необходимо изменить взаимодействие между блоками так, чтобы оно всегда проходило через монитор безопасности. Для этого потребуется изменить соответствующие реализации внутренних блоков.

# %% [markdown]
# Ниже пример для блока навигации. Обратите внимание на выделенные строки и комментарии.
#
# ```python
# from src.navigation_system import BaseNavigationSystem
# from src.config import CONTROL_SYSTEM_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME
#
#
# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):
#         # событие для системы управления,
#         # поэтому в destination указываем CONTROL_SYSTEM_QUEUE_NAME
#         event = Event(source=self.event_source_name,
# >>>                      destination=CONTROL_SYSTEM_QUEUE_NAME,
#                       operation="position_update", parameters=self._position
#                       )
#         # но событие отправляем сначала на проверку в монитор безопасности,
#         # поэтому используем очередь с именем SECURITY_MONITOR_QUEUE_NAME
# >>>        security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         security_monitor_q.put(event)
#         # а в систему управления наше событие монитор безопасности отправит сам, если найдёт разрешающую эту операцию политику безопасности
#
# navigation_system = NavigationSystem(queues_dir=queues_dir)
# ```

# %% [markdown]
# from src.navigation_system import BaseNavigationSystem
# from src.config import CONTROL_SYSTEM_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME
#
#
# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):
#         event = Event(source=self.event_source_name,
#                       destination=CONTROL_SYSTEM_QUEUE_NAME,
#                       operation="position_update", parameters=self._position
#                       )
#         security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         security_monitor_q.put(event)
#
# navigation_system = NavigationSystem(queues_dir=queues_dir)

# %% [markdown]
# В файле tests/module/test_security_monitor.py можно увидеть тест логики работы монитора безопасности. Запустить его можно следующей командой:

# %%
# !pytest -svk security_monitor
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-8.3.4, pluggy-1.5.0 -- /bin/python
# cachedir: .pytest_cache
# rootdir: /home/user/projects/delivery-car-jupyter/ciac
# configfile: pytest.ini
# testpaths: tests
# plugins: anyio-4.3.0
# collected 10 items / 9 deselected / 1 selected
#
# tests/module/test_security_monitor.py::test_security_policies [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь security
# [ИНФО][SECURITY] создан монитор безопасности
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission')]
# [ОТЛАДКА][SECURITY] проверка события Event(source='communication', destination='control', operation='set_mission', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ОТЛАДКА][SECURITY] событие разрешено политиками, выполняем
# [ОТЛАДКА][SECURITY] проверка события Event(source='control', destination='safety', operation='set_speed', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission'), SecurityPolicy(source='control', destination='safety', operation='set_speed')]
# [ОТЛАДКА][SECURITY] проверка события Event(source='control', destination='safety', operation='set_speed', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ОТЛАДКА][SECURITY] событие разрешено политиками, выполняем
# [ОТЛАДКА][SECURITY] проверка события Event(source='communication', destination='cargo', operation='release_cargo', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# PASSED
#
# ======================= 1 passed, 9 deselected in 0.02s ========================

# %% [markdown]
# В одном кодовом блоке ниже (или нескольких - как будет удобнее)  сделайте следующее
#
# 1. Измените реализацию монитора безопасности в части правил проверки передаваемых сообщений в мониторе безопасности
# 2. Измените параметры отправки сообщений между элементами бортовых систем (блоками 1-7), чтобы они всегда отправлялись в очередь монитора безопасности (отправитель и получатель при этом не меняются)
# 3. После всех изменений убедитесь в том, что машинка по-прежнему успешно выполняет маршрутное задание и доставляет груз
# 4. Дополнительные баллы принесут автоматические тесты правил безопасности в файле tests/module/test_security_monitor.py - можно проверить, что все новые политики работают как ожидаются, а недопустимые взаимодействия (т.е. таких стрелок нет на рис. 8) блокируются

# %%
# добавьте изменения сюда

# %% [markdown]
# На этом модуль 3 завершён!
#
# Если у вас всё получилось, то вы создали защищённую автономную машинку - ещё уже не так-то просто использовать для нанесения критического ущерба людям и имуществу, потому что самые критические режимы проверяются вашим Ограничителем, а если вы ещё и внедрили Монитор Безопасности, то теперь злоумышленнику гораздо сложнее атаковать внутренние блоки, даже если он смог проникнуть в какую-то бортовую систему или внедрить вредоносный код.
#
# Осталось проверить эффективность получившейся защиты на полной трассе - в этом и заключается модуль 4 задания, для перехода к которому нужно открыть блокнот с именем cyberimmunity--autonomous-car-m4. Успеха!
