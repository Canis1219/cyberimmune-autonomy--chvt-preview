# %% [markdown]
# # Кибериммунная автономность$\\$Создание конструктивно защищённого автономного наземного транспортного средства$\\$Модуль 3
#
# ## О документе
#
# Версия 1.03
#
# Модуль 3 для регионального этапа соревнований по кибериммунной автономности

# %% [markdown]
# ### Модуль 3. Внедрение блоков функциональной и информационной безопасности
# #### Общая идея
#
# Ключевая идея кибериммунной автономности заключается в том, чтобы уже на этапе проектирования внедрить защиту от кибератак как снаружи, так и изнутри - т.е. через уязвимые бортовые информационные системы.
# Мы исходим из того, что абсолютно защищённых систем не бывает, чем больше и сложнее код, тем проще одним ("плохим") в нём спрятать уязвимости, а другим ("хорошим", но уставшим) эти уязвимости не найти.
#
# Поэтому необходимо сделать так, чтобы наиболее критичный код был отделён от некритичного и протестирован особенно тщательно - таким образом можно снизить вероятность успешной атаки и затруднить задачу атакующим.

# %% [markdown]
# #### Цели и предположения безопасности
#
# ##### Цели безопасности
# Устойчивость кибериммунных систем к атакам выражается в том, что поставленные заказчиком **цели безопасности** (ЦБ) не нарушаются даже в условиях кибератак (снаружи и изнутри).
#
# Для наших автономных машинок заказчиком поставлены следующие ЦБ:
#
# 1. При любых обстоятельствах АНТС осуществляет перемещения в пределах заданных ограничений
#
# 2. При любых обстоятельствах АНТС выполняет только аутентичный (подлинный) маршрут
#
# 3. При любых обстоятельствах АНТС оставляет груз только в авторизованном пункте назначения
#
# Ниже используется цифро-буквенное обозначение целей безопасности - например, ЦБ1 - первая цель безопасности из списка выше.
#
# ##### Предположения безопасности
# При этом заказчик согласовал с разработчиками следующие **предположения безопасности** (ПБ) - утверждения о смежных системах, которые снимают с разработчиков часть задач для обеспечения целей безопасности:
#
# 1. При любых обстоятельствах только авторизованный персонал имеет физический доступ к критическим узлам АНТС
#
# 2. При любых обстоятельствах только аутентичные и авторизованные операторы имеют доступ к системе планирования заданий
#
# 3. Аутентичные и авторизованные операторы обладают необходимой квалификацией и являются благонадёжными (т.е. не пытаются намеренно причинить ущерб системе или третьим лицам, используя доступ к АНТС)
#
# Ниже используется цифро-буквенное обозначение предположений безопасности - например, ПБ1 - первое предположение безопасности из списка выше.

# %% [markdown]
# ### Киберпрепятствия
#
# Прежде чем мы начнём внедрять механизмы безопасности, посмотрим, что произойдёт с нашей машинкой, если бортовые системы начнут вести себя не так, как мы ожидаем.
#
# Для этого активируем специальный режим работы системы управления и снова запустим машинку по тому же маршруту, который был в конце модуля 2.
#
# После инициализации системы управления добавьте следующую строку
# ```python
# control_system.enable_surprises()
# ```

# %% [markdown]
# Но вначале нужно из модуля 2 скопировать сюда ваши текущие наработки, а именно ваши реализации классов коммуникационного шлюза (CommunicationGateway), систему навигации (NavigationSystem), управления (ControlSystem), также будем использовать маршрут, который вы создали.

# %%
from multiprocessing import Queue
from src.communication_gateway import BaseCommunicationGateway
from src.config import CONTROL_SYSTEM_QUEUE_NAME
from src.event_types import Event
from src.config import SERVOS_QUEUE_NAME
from src.control_system import BaseControlSystem
from src.config import CONTROL_SYSTEM_QUEUE_NAME
from src.navigation_system import BaseNavigationSystem

class CommunicationGateway(BaseCommunicationGateway):
    """Класс для реализации логики взаимодействия с системой планирования заданий.
    Работает в отдельном процессе, поэтому создаётся как наследник класса Process.
    """
    def _send_mission_to_consumers(self):
        """Метод для отправки сообщения с маршрутным заданием в систему управления."""
        
        # Получаем имя очереди системы управления
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME

        # Создаём событие с маршрутным заданием
        event = Event(
            source=BaseCommunicationGateway.event_source_name,
            destination=control_q_name,
            operation="set_mission",
            parameters=self._mission
        )

        # Ищем в каталоге нужную очередь
        control_q: Queue = self._queues_dir.get_queue(control_q_name)

        # Отправляем событие в найденную очередь
        control_q.put(event)
        
class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def _send_speed_and_direction_to_consumers(self, speed, direction):
        servos_q_name = SERVOS_QUEUE_NAME # замените на правильное название очереди
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(
            source=BaseControlSystem.event_source_name,
            destination=servos_q_name,
            operation="set_speed",
            parameters=speed
        )                   # замените на код создания сообщения со скоростью для приводов
                            # подсказка, требуемая операция - set_speed

        # отправка сообщения с желаемым направлением
        event_direction = Event(
            source=BaseControlSystem.event_source_name,
            destination=servos_q_name,
            operation="set_direction",
            parameters=direction
        )                       # замените на код создания сообщения с направлением для приводов
                                # подсказка, требуемая операция - set_direction

        servos_q.put(event_speed)
        servos_q.put(event_direction)       

class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):                              
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME # замените на правильное название очереди
        event = Event(
            source=BaseNavigationSystem.event_source_name,
            destination=control_q_name,
            operation="position_update",
            parameters=self._position           # Координаты текущего местоположения
        )                                       # замените на код создания сообщения с координатами для системы управления 
                                                # подсказка, требуемая операция - position_update
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)

# %% [markdown]
# Если у вас настроена и работает СУПА, установите в True значение переменной afcs_present

# %%
afcs_present = True

# %% [markdown]
# Поменяем идентификатор машинки для этого модуля

# %%
car_id = "m3"

# %%
# используем то же маршрутное задание, которое было в модуле 2
from time import sleep
from geopy import Point as GeoPoint

from src.queues_dir import QueuesDirectory
from src.servos import Servos
from src.sitl import SITL
from src.cargo_bay import CargoBay
from src.mission_planner import MissionPlanner
from src.config import LOG_ERROR, LOG_INFO
from src.mission_planner_mqtt import MissionSender
from src.mission_planner import Mission
from src.sitl_mqtt import TelemetrySender
from src.system_wrapper import SystemComponentsContainer
from src.wpl_parser import WPLParser

afcs_present = True

car_id = "m3"

# возьмём маршрут из модуля 2
wpl_file = "module2.wpl"

parser = WPLParser(wpl_file)    
points = parser.parse()
print(points)

from src.mission_type import GeoSpecificSpeedLimit
speed_limits = [
    GeoSpecificSpeedLimit(0, 20),
    GeoSpecificSpeedLimit(2, 60),
    GeoSpecificSpeedLimit(7, 20),
]


home = points[0]
mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)

# каталог очередей для передачи сообщений между блоками
queues_dir = QueuesDirectory() 

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

communication_gateway = CommunicationGateway(
    queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)

navigation_system = NavigationSystem(
    queues_dir=queues_dir, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

# по аналогии собираем все блоки в одном кузове
system_components = SystemComponentsContainer(
    components=[
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system
    ] if afcs_present else [
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system
    ])

#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
#################################

system_components.start()

# ограничение поездки по времени
# параметр sleep - время в секундах,
# настройте этот параметр так, чтобы ваша машинка завершила маршрут
# в случае превышения времени выполнения ячейки на более чем 10 секунд от заданного, 
# допустимо перезапустить вычислительное ядро и повторно выполнить весь блокнот, штрафные очки за это не начисляются
# при условии, что повторный запуск закончился успешно
sleep(5)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
del system_components
# Out:
# [Point(59.869328, 29.827365, 0.0), Point(59.868883, 29.824322, 0.0), Point(59.869184, 29.823516, 0.0), Point(59.870481, 29.828145, 0.0), Point(59.870456, 29.836566, 0.0), Point(59.869963, 29.844628, 0.0), Point(59.869206, 29.848098, 0.0), Point(59.870235, 29.849917, 0.0), Point(59.870743, 29.849644, 0.0), Point(59.871044, 29.849363, 0.0)]
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][CONTROL] старт системы управления
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 20:13:31.922729
# [ИНФО][CONTROL] новая скорость 20 (была 0)
# [ИНФО][CONTROL] новое направление 253 (было 0)

# %% [markdown]
# Итак, в отличие от, надеемся, успешного завершения маршрута в модуле 2, сейчас ваша машинка ведёт себя совсем иначе. Например, она внезапно едет в совершенно другую сторону (это особенно хорошо видно при использовании СУПА).
# И это ещё не всё, что может пойти не так..
#
# В этой реализации не очень много кода, теоретически, вы можете его весь изучить и устранить "незадокументированные возможности", однако в реальных системах кода гораздо больше. Например, кодовая база проекта с открытым исходным кодом ArduPilot, реализующего в том числе логику автопилота, составляет примерно миллион строк.
#
# Сколько времени вам понадобится, чтобы изучить и протестировать миллион строк кода? А ведь придётся проводить анализ и каждого обновления.. При этом неприятности могут быть хорошо спрятанными и на первый взгляд безобидными, вряд ли злоумышленники облегчат задачу и назовут свои изменения, например, "hacking_the_system" или "allowing_secret_remote_access". Вредоносный код может выглядеть совершенно безобидно или маскироваться под программный дефект.
#
# Поэтому тщательный анализ потребует большого количества ресурсов (человеческих, вычислительных, временныз), что стоит дорого.
#
# Логичным выходом является выделение критичных для целей безопасности проверок в отдельный блок, который протестировать должно быть гораздо проще.

# %% [markdown]
# #### Задания
#
# В этом модуле задание будет состоять из двух частей разной сложности:
#
# **3.1. добавить новый блок - "Ограничитель"** - этот модуль должен будет обеспечить соблюдение ограничений, указанных в маршрутном задании - это необходимо для обеспечения ЦБ1
#
# **З.2. *(задание повышенной сложности)* добавить монитор безопасности (МБ)** - он должен контролировать все взаимодействия *бортовых систем* (т.е. не включая планировщик и симулятор) и не давать блокам взаимодействовать друг с другом непредусмотренным образом - например, блок №5 может принимать команды только от №3, попытка передать команду в №5 от №2 должна блокироваться нашим монитором безопасности - потенциально это необходимо для обеспечения всех ЦБ

# %% [markdown]
# Для выполнения первой части задачи 3.1. необходимо для начала изменить архитектуру АНТС как показано на рис. 5
#
# ![Архитектура системы с ограничителем](images/ciac-arch-m31.png)
#
# Рис. 5. Архитектура АНТС с ограничителем (для ЦБ1)

# %% [markdown]
# Код базового класса Ограничителя находится в файле src/safety_block.py
#
# По аналогии с заданием в модуле 1, необходимо создать на основе этого класса свой собственный под названием SafetyBlock, в котором реализовать передачу команд в приводы движения, только перед эти необходимо ещё и проконтролировать их безопасность.
#
# Также необходимо реализовать передачу маршрутного задания из CommunicationGateway в SafetyBlock и координат из модуля Navigation в соответствии со стрелками на рис.5 выше.
#
# Если всё сделано правильно, то Ограничителю будет известно следующее
#
# - _mission - текущее маршрутное задание
# - _position - текущие координаты
#
# После проверки нужно установить значение внутренних переменных
# - _speed - текущая (допустимая) скорость
# - _direction - текущее (допустимое) направление
#
# Желательно завершить следование по маршруту. В критической ситуации, если продолжение маршрута невозможно, следует установить значение скорости и направления в 0, после чего передать эти команды в блок приводов (Servos)

# %% [markdown]
# Базовый сценарий для новой архитектуры можно представить следующим образом (см. рис. 6)
#
# ![Базовый сценарий с блоком безопасности](images/basic-scenario-with-safety-block1.png)
#
# Рис. 6. Базовый сценарий с блоком безопасности

# %% [markdown]
# Заготовка кода SafetyBlock
#
# ```python
# class SafetyBlock(BaseSafetyBlock):
#     """ класс ограничений безопасности """
#
#     def _set_new_direction(self, direction: float):
#         """ установка нового направления перемещения """
#         self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
#         self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
#         self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
#         # TODO реализовать контроль безопасности изменения направления
#         self._direction = direction
#         self._send_direction_to_consumers()
#
#     def _set_new_speed(self, speed: float):
#         """ установка новой скорости """
#         # TODO реализовать контроль безопасности изменения скорости
#         self._speed = speed
#         self._send_speed_to_consumers()
#
#     def _send_speed_to_consumers(self):
#         self._log_message(LOG_DEBUG, "отправляем скорость получателям")
#         servos_q_name = SERVOS_QUEUE_NAME
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)
#
#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(source=self.event_source_name,
#                             destination=servos_q_name,
#                             operation="set_speed",
#                             parameters=self._speed
#                             )
#         servos_q.put(event_speed)
#
#     def _send_direction_to_consumers(self):
#         self._log_message(LOG_DEBUG, "отправляем направление получателям")
#
#         servos_q_name = SERVOS_QUEUE_NAME
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)
#
#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(source=self.event_source_name,
#                             destination=servos_q_name,
#                             operation="set_direction",
#                             parameters=self._direction
#                             )
#         servos_q.put(event_speed)
# ```

# %%
# 1. скопируйте сюда код заготовки из предыдущей ячейки и напишите свою реализацию класса SafetyBlock
import math
from src.safety_block import BaseSafetyBlock
from src.config import LOG_ERROR, LOG_DEBUG, LOG_INFO, SERVOS_QUEUE_NAME

class SafetyBlock(BaseSafetyBlock):
    """ Класс ограничений безопасности """

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"новые координаты: {direction}")
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")

        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, "Неизвестный маршрут или позиция! Остановка.")
            self._stop_the_car()
            return
        
        target_point = self._route.next_point()
        current_point = self._position
        target_direction = self._calculate_bearing(current_point, target_point)
        tolerance = 1

        if (abs(target_direction - direction) > tolerance):
            self._log_message(LOG_ERROR, "Направление не совпадает с маршрутом! Остановка.")
            self._stop_the_car()
            return
        
        self._direction = direction    
        self._send_direction_to_consumers()

    def _calculate_bearing(self, start: GeoPoint, end: GeoPoint) -> float:
        delta_longitude = end.longitude - start.longitude
        x = math.sin(math.radians(delta_longitude)) * \
            math.cos(math.radians(end.latitude))
        y = math.cos(math.radians(start.latitude)) * math.sin(math.radians(end.latitude)) - \
            math.sin(math.radians(start.latitude)) * math.cos(math.radians(end.latitude)) * \
            math.cos(math.radians(delta_longitude))

        initial_bearing_rad = math.atan2(x, y)

        # Преобразуем радианы в градусы
        initial_bearing_deg = math.degrees(initial_bearing_rad)

        # Нормализуем значение в диапазоне [0, 360]
        compass_bearing = (initial_bearing_deg + 360) % 360

        return compass_bearing

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        self._log_message(LOG_INFO, f"новая скорость: {speed}")
        self._log_message(LOG_INFO, f"текущая скорость: {self._speed}")

        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, "Неизвестный маршрут или позиция! Остановка.")
            self._stop_the_car()
            return 
        
        allowed_speed = self._route.calculate_speed()
        
        if speed > allowed_speed:
            self._log_message(LOG_ERROR, f"Скорость {speed} превышает лимит {allowed_speed}. Ограничиваем.")
            self._speed = allowed_speed
        else:
            self._speed = speed
        
        self._send_speed_to_consumers()

    def _stop_the_car(self):
        self._speed = 0
        self._direction = 0    
        
        self._send_speed_to_consumers()  
        self._send_direction_to_consumers()

    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed)
        servos_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем направление получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        event_direction = Event(source=self.event_source_name,
                                destination=servos_q_name,
                                operation="set_direction",
                                parameters=self._direction)
        servos_q.put(event_direction)

# %%
from multiprocessing import Queue
from src.event_types import Event
from src.communication_gateway import BaseCommunicationGateway
from src.control_system import BaseControlSystem
from src.navigation_system import BaseNavigationSystem
from src.config import CONTROL_SYSTEM_QUEUE_NAME
from src.config import SAFETY_BLOCK_QUEUE_NAME

class CommunicationGateway(BaseCommunicationGateway):
    """Класс для реализации логики взаимодействия с системой планирования заданий.
    Работает в отдельном процессе, поэтому создаётся как наследник класса Process.
    """
    def _send_mission_to_consumers(self):
        """Метод для отправки сообщения с маршрутным заданием в систему управления."""
        
        # Получаем имя очереди системы управления
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME 

        # Создаём событие с маршрутным заданием
        event_control = Event(
            source=BaseCommunicationGateway.event_source_name,
            destination=control_q_name,
            operation="set_mission",
            parameters=self._mission
        )
        event_safety = Event(
            source=BaseCommunicationGateway.event_source_name,
            destination=safety_q_name,
            operation="set_mission",
            parameters=self._mission
        )

        # Ищем в каталоге нужную очередь
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        # Отправляем событие в найденную очередь
        control_q.put(event_control)
        safety_q.put(event_safety)
        
class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def _send_speed_and_direction_to_consumers(self, speed, direction):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(
            source=BaseControlSystem.event_source_name,
            destination=safety_q_name,
            operation="set_speed",
            parameters=speed
        )                   # замените на код создания сообщения со скоростью для приводов
                            # подсказка, требуемая операция - set_speed

        # отправка сообщения с желаемым направлением
        event_direction = Event(
            source=BaseControlSystem.event_source_name,
            destination=safety_q_name,
            operation="set_direction",
            parameters=direction
        )                       # замените на код создания сообщения с направлением для приводов
                                # подсказка, требуемая операция - set_direction

        safety_q.put(event_speed)
        safety_q.put(event_direction)       

class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):                              
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME # замените на правильное название очереди

        event_safety = Event(
            source=BaseNavigationSystem.event_source_name,
            destination=safety_q_name,
            operation="position_update",
            parameters=self._position           # Координаты текущего местоположения
        )                                       # замените на код создания сообщения с координатами для системы управления 
                                                # подсказка, требуемая операция - position_update

        event_control = Event(
            source=BaseNavigationSystem.event_source_name,
            destination=control_q_name,
            operation="position_update",
            parameters=self._position          
        )     
                                                
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        
        safety_q.put(event_safety)
        control_q.put(event_control)

communication_gateway = CommunicationGateway(queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)
navigation_system = NavigationSystem(queues_dir=queues_dir, log_level=LOG_ERROR)
# Out:
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation

# %%
# создадим все остальные компоненты

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)
# Out:
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель

# %%
# соберём все компоненты для запуска
# в зависимости от наличия СУПА используем разный набор компонентов - с передачей телеметрии или без

system_components = SystemComponentsContainer(
components=[
        # вариант компонентов с передачей телеметрии в СУПА
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ] if afcs_present else [
        # вариант компонентов для конфигурации без СУПА
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ])

system_components.start()

# настройте этот параметр так, чтобы проверить работу ограничителя
sleep(180)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()

# %% [markdown]
# #### Обеспечение ЦБ3: контроль доставки груза
#
# С помощью логики ограничителя выше мы реализовали обеспечение ЦБ1 (соблюдение заданных ограничений), однако есть ещё ЦБ3 (отгрузка только в заданной точке), не говоря о ЦБ2 (следование только по аутентичному маршруту).
#
# Для обеспечения ЦБ3 необходимо сделать следующее
# 1. изменить последовательность передачи команд, чтобы в блок управления грузовым отсеком (CargoBay) команды приходили только после проверки в Ограничителе
# 2. доработайте реализацию Ограничителя, чтобы команда на выгрузку передавалась в CargoBay только в конечной точке маршрута
# 3. продумайте логику работы блока безопасности, если система управления полностью перестанет работать (т.е. перестанет отправлять новые команды).
#
# Изменённая архитектура приведена на рис. 7.
#
# ![Ограничитель для обеспечения ЦБ1 и ЦБ3](images/ciac-arch-m312.png)
#
# Рис. 7. Ограничитель для обеспечения ЦБ1 и ЦБ3

# %%
# напишите свой код в этой ячейке, запустите машинку по маршруту, убедитесь, 
# что в конечной (и только в конечной!) точке CargoBay получает команду и успешно выполняет выгрузку

import math
from multiprocessing import Queue
from src.event_types import Event
from src.communication_gateway import BaseCommunicationGateway
from src.control_system import BaseControlSystem
from src.navigation_system import BaseNavigationSystem
from src.safety_block import BaseSafetyBlock
from src.config import LOG_ERROR, LOG_DEBUG, LOG_INFO, SERVOS_QUEUE_NAME, CARGO_BAY_QUEUE_NAME, CONTROL_SYSTEM_QUEUE_NAME, SAFETY_BLOCK_QUEUE_NAME

class CommunicationGateway(BaseCommunicationGateway):
    """Класс для реализации логики взаимодействия с системой планирования заданий.
    Работает в отдельном процессе, поэтому создаётся как наследник класса Process.
    """
    def _send_mission_to_consumers(self):
        """Метод для отправки сообщения с маршрутным заданием в систему управления."""
        
        # Получаем имя очереди системы управления
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME 

        # Создаём событие с маршрутным заданием
        event_control = Event(
            source=BaseCommunicationGateway.event_source_name,
            destination=control_q_name,
            operation="set_mission",
            parameters=self._mission
        )
        event_safety = Event(
            source=BaseCommunicationGateway.event_source_name,
            destination=safety_q_name,
            operation="set_mission",
            parameters=self._mission
        )

        # Ищем в каталоге нужную очередь
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        # Отправляем событие в найденную очередь
        control_q.put(event_control)
        safety_q.put(event_safety)
        
class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def _send_speed_and_direction_to_consumers(self, speed, direction):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(
            source=BaseControlSystem.event_source_name,
            destination=safety_q_name,
            operation="set_speed",
            parameters=speed
        )                   # замените на код создания сообщения со скоростью для приводов
                            # подсказка, требуемая операция - set_speed

        # отправка сообщения с желаемым направлением
        event_direction = Event(
            source=BaseControlSystem.event_source_name,
            destination=safety_q_name,
            operation="set_direction",
            parameters=direction
        )                       # замените на код создания сообщения с направлением для приводов
                                # подсказка, требуемая операция - set_direction

        safety_q.put(event_speed)
        safety_q.put(event_direction)   

    
    def _release_cargo(self):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME 
        
        event_release_cargo = Event(
            source=BaseControlSystem.event_source_name,
            destination=safety_q_name,
            operation="release_cargo",
            parameters=None
        )                      

        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event_release_cargo)   


    def _lock_cargo(self):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME 
        
        event_lock_cargo = Event(
            source=BaseControlSystem.event_source_name,
            destination=safety_q_name,
            operation="lock_cargo",
            parameters=None
        )                      

        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event_lock_cargo)    

class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):                              
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME # замените на правильное название очереди

        event_safety = Event(
            source=BaseNavigationSystem.event_source_name,
            destination=safety_q_name,
            operation="position_update",
            parameters=self._position           # Координаты текущего местоположения
        )                                       # замените на код создания сообщения с координатами для системы управления 
                                                # подсказка, требуемая операция - position_update

        event_control = Event(
            source=BaseNavigationSystem.event_source_name,
            destination=control_q_name,
            operation="position_update",
            parameters=self._position          
        )     
                                                
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        
        safety_q.put(event_safety)
        control_q.put(event_control)

class SafetyBlock(BaseSafetyBlock):
    """ Класс ограничений безопасности """

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"новые координаты: {direction}")
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")

        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, "Неизвестный маршрут или позиция! Остановка.")
            self._stop_the_car()
            return
        
        target_direction = self._calculate_bearing(self._position, self._route.next_point())
        tolerance = 1

        if (abs(target_direction - direction) > tolerance):
            self._log_message(LOG_ERROR, "Направление не совпадает с маршрутом! Остановка.")
            self._stop_the_car()
            return
        
        self._direction = direction    
        self._send_direction_to_consumers()

    def _calculate_bearing(self, start: GeoPoint, end: GeoPoint) -> float:
        delta_longitude = end.longitude - start.longitude
        x = math.sin(math.radians(delta_longitude)) * \
            math.cos(math.radians(end.latitude))
        y = math.cos(math.radians(start.latitude)) * math.sin(math.radians(end.latitude)) - \
            math.sin(math.radians(start.latitude)) * math.cos(math.radians(end.latitude)) * \
            math.cos(math.radians(delta_longitude))

        initial_bearing_rad = math.atan2(x, y)

        # Преобразуем радианы в градусы
        initial_bearing_deg = math.degrees(initial_bearing_rad)

        # Нормализуем значение в диапазоне [0, 360]
        compass_bearing = (initial_bearing_deg + 360) % 360

        return compass_bearing

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        self._log_message(LOG_INFO, f"новая скорость: {speed}")
        self._log_message(LOG_INFO, f"текущая скорость: {self._speed}")

        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, "Неизвестный маршрут или позиция! Остановка.")
            self._stop_the_car()
            return 
        
        allowed_speed = self._route.calculate_speed()
        
        if speed > allowed_speed:
            self._log_message(LOG_ERROR, f"Скорость {speed} превышает лимит {allowed_speed}. Ограничиваем.")
            self._speed = allowed_speed
        else:
            self._speed = speed
        
        self._send_speed_to_consumers()

    def _stop_the_car(self):
        self._speed = 0
        self._direction = 0    
        
        self._send_speed_to_consumers()  
        self._send_direction_to_consumers()
        self._send_lock_cargo_to_consumers()

    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed)
        servos_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем направление получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        event_direction = Event(source=self.event_source_name,
                                destination=servos_q_name,
                                operation="set_direction",
                                parameters=self._direction)
        servos_q.put(event_direction)

    def _lock_cargo(self, _):
        self._log_message(LOG_INFO, "Блокировка грузового отсека")
        self._send_lock_cargo_to_consumers()

    def _release_cargo(self, _):
        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, "Неизвестный маршрут или позиция! Остановка.")
            self._stop_the_car()
            return 

        if not self._route.route_finished:
            self._log_message(LOG_INFO, "Маршрут не завершён, выгрузка невозможна!")
            return
        
        self._send_release_cargo_to_consumers()
    

    def _send_lock_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду на блокировку грузового отсека")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="lock_cargo",
            parameters=None
        )
        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        cargo_q.put(event)

    def _send_release_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду на разблокировку грузового отсека")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="release_cargo",
            parameters=None
        )
        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        cargo_q.put(event)

communication_gateway = CommunicationGateway(queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)
navigation_system = NavigationSystem(queues_dir=queues_dir, log_level=LOG_ERROR)
# Out:
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation

# %% [markdown]
# Выполнено!)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### *Опциональное задание повышенной сложности* Обеспечение ЦБ2
#
# **Перед началом работы над этой задачей рекомендуем сохранить все текущие изменения в git репозитории (git commit, git push).**
#
# Напомним цель безопасности №2 (ЦБ2): "При любых обстоятельствах АНТС выполняет только аутентичный (подлинный) маршрут"
#
# Обеспечение ЦБ2 потребует
# - внедрения механизма **контроля аутентичности маршрутного задания** (mission), а значит
# - помимо изменения **блока безопасности** (SafetyBlock), модификации
#   - системы **планирования задания** (MissionPlanner)
#   - **коммуникационного шлюза** (CommunicationGateway)
#   - и, возможно, **системы управления** (ControlSystem).
#
# Для решения этой задачи допустимо менять код соответствующих модулей в папке src.
#
# Возможным решением является внедрение механизма цифровой подписи, верификацией которой будет заниматься блок безопасности. В этой ситуации если коммуникационный шлюз (блок "1. Связь" на рис. 5 в модуле 1) оказался скомпрометированным и изменил маршрутное задание, оно не должно пройти проверку подлинности в блоке безопасности.
#
# **Рекомендуем эту задачу делать в последнюю очередь**, *после успешного выполнения модуля 4*, поскольку успешное выполнение модуля 4 принесёт больше баллов, чем внедрение цифровой подписи и обеспечение ЦБ2.
# К сведению, реализованные в этой версии киберпрепятствия не предполагают компрометацию маршрутного задания.
#
# Конечно, если будут решены все основные задачи и к тому же обеспечен контроль аутентичности маршрутного задания, такая работа с высокой вероятностью окажется лучшей.

# %%
# если вы собираетесь выполнить это задание, напишите в этой ячейке код выполнения изменённых блоков. 
# cам код допускается редактировать в папке src
# в случае успешной реализации машинка должна успешно пройти по маршруту, а в случае искажения маршрутного задания в блоке коммуникационного шлюза должна остаться на месте, 
# при этом именно блок безопасности должен заблокировать движение

# %% [markdown]
# ### Задание 3.2. Монитор безопасности

# %% [markdown]
# В текущей реализации каждый блок сам решает куда и какие данные ему отправлять. Это приемлемо, когда каждый блок рассматривается как благонадёжный. Однако нельзя исключать ситуацию успешной компрометации какого-либо из блоков (одного или нескольких), в результате которой злоумышленник может получить полный контроль над частью системы.
#
# В такой ситуации необходимо выстроить внутреннюю "поверхность защиты", частью этой системы уже является блок "Ограничитель", однако необходимо сделать так, чтобы соответствующие запросы проходили только через него, а не в обход.
#
# Для решения этой задачи необходимо добавить новый блок "Монитор безопасности". Его задача - обеспечить контроль направления информационных потоков, допустить передачу данных только между теми блоками и в тех направлениях, которые задуманы архитектором системы. Тогда, например, попытка передать команду из системы управления напрямую в сервоприводы в обход ограничителя будет заблокирована.
#
# Возможно, возникнет вопрос, а что помешает злоумышленнику отправить команду в обход этого монитора безопасности. В рамках этой учебной инфраструктуры особо ничего, однако при разработке реальной системы можно использовать специализированные микроядерные операционные системы, такие как, например, KasperskyOS, которые обеспечат обязательное вовлечение монитора безопасности в контроль взаимодействия между блоками.
#
# Архитектура системы для решения задачи 3.2 должна выглядеть как на рис.8:
#
# ![Архитектура системы с монитором безопасности](images/ciac-arch-m32.png)
#
# Рис. 8. Архитектура бортовых систем с монитором безопасности

# %% [markdown]
# Базовый класс модуля безопасности находится в файле src/security_monitor.py, его менять не нужно.
#
# В следующей ячейке находится реализация класса SecurityMonitor

# %%
from src.security_monitory import BaseSecurityMonitor
from src.security_policy_type import SecurityPolicy

from src.config import COMMUNICATION_GATEWAY_QUEUE_NAME, LOG_DEBUG, LOG_ERROR, LOG_INFO
    
    
class SecurityMonitor(BaseSecurityMonitor):
    """ класс монитора безопасности """

    def __init__(self, queues_dir):
        super().__init__(queues_dir)
        self._init_set_security_policies()

    def _init_set_security_policies(self):
        """ инициализация политик безопасности """
        default_policies = [
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='set_mission')
        ]
        self.set_security_policies(policies=default_policies)        

    def set_security_policies(self, policies):
        """ установка новых политик безопасности """
        self._security_policies = policies
        self._log_message(
            LOG_INFO, f"изменение политик безопасности: {policies}")

    def _check_event(self, event: Event):
        """ проверка входящих событий """
        self._log_message(
            LOG_DEBUG, f"проверка события {event}, по умолчанию выполнение запрещено")

        authorized = False
        request = SecurityPolicy(
            source=event.source,
            destination=event.destination,
            operation=event.operation)

        if request in self._security_policies:
            self._log_message(
                LOG_DEBUG, "событие разрешено политиками, выполняем")
            authorized = True

        if authorized is False:
            self._log_message(LOG_ERROR, f"событие не разрешено политиками безопасности! {event}")
        return authorized

# %% [markdown]
# Обратите внимание на этот код:
# ```python
#     def _init_set_security_policies(self):
#         """ инициализация политик безопасности """
#         default_policies = [
#             SecurityPolicy(
#                 source=COMMUNICATION_GATEWAY_QUEUE_NAME,
#                 destination=CONTROL_SYSTEM_QUEUE_NAME,
#                 operation='set_mission')
#         ]
#         self.set_security_policies(policies=default_policies)
# ```
#
# В нём инициализируется политика безопасности, разрешающая запрос set_mission от коммуникационного шлюза в систему управления.
#
# Код политики безопасности в строка 6-9:
# ```python
# SecurityPolicy(
#                 source=COMMUNICATION_GATEWAY_QUEUE_NAME,
#                 destination=CONTROL_SYSTEM_QUEUE_NAME,
#                 operation='set_mission')
# ```
#
# Шаблон политики безопасности описан в файле src/security_policy_type.py:
# ```python
# @dataclass
# class SecurityPolicy:
#     """ политика безопасности """
#     source: str         # отправитель запроса
#     destination: str    # получатель
#     operation: str      # запрашиваемая операция
#
# ```
#
# По аналогии в методе _init_set_security_policies допишите другие политики безопасности, чтобы разрешить взаимодействия согласно диаграмме на рис.7. выше.

# %% [markdown]
# Теперь необходимо изменить взаимодействие между блоками так, чтобы оно всегда проходило через монитор безопасности. Для этого потребуется изменить соответствующие реализации внутренних блоков.

# %% [markdown]
# Ниже пример для блока навигации. Обратите внимание на выделенные строки и комментарии.
#
# ```python
# from src.navigation_system import BaseNavigationSystem
# from src.config import CONTROL_SYSTEM_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME
#
#
# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):
#         # событие для системы управления,
#         # поэтому в destination указываем CONTROL_SYSTEM_QUEUE_NAME
#         event = Event(source=self.event_source_name,
# >>>                      destination=CONTROL_SYSTEM_QUEUE_NAME,
#                       operation="position_update", parameters=self._position
#                       )
#         # но событие отправляем сначала на проверку в монитор безопасности,
#         # поэтому используем очередь с именем SECURITY_MONITOR_QUEUE_NAME
# >>>        security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         security_monitor_q.put(event)
#         # а в систему управления наше событие монитор безопасности отправит сам, если найдёт разрешающую эту операцию политику безопасности
#
# navigation_system = NavigationSystem(queues_dir=queues_dir)
# ```

# %% [markdown]
# ```python
# from src.navigation_system import BaseNavigationSystem
# from src.config import CONTROL_SYSTEM_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME
#
#
# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):
#         event = Event(source=self.event_source_name,
#                       destination=CONTROL_SYSTEM_QUEUE_NAME,
#                       operation="position_update", parameters=self._position
#                       )
#         security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         security_monitor_q.put(event)
#
# navigation_system = NavigationSystem(queues_dir=queues_dir)

# %% [markdown]
# В файле tests/module/test_security_monitor.py можно увидеть тест логики работы монитора безопасности. Запустить его можно следующей командой:

# %%
# !pytest -svk security_monitor
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-8.3.4, pluggy-1.5.0 -- /bin/python
# cachedir: .pytest_cache
# rootdir: /home/user/projects/delivery-car-jupyter/ciac
# configfile: pytest.ini
# testpaths: tests
# plugins: anyio-4.3.0
# collected 10 items / 9 deselected / 1 selected
#
# tests/module/test_security_monitor.py::test_security_policies [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь security
# [ИНФО][SECURITY] создан монитор безопасности
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission')]
# [ОТЛАДКА][SECURITY] проверка события Event(source='communication', destination='control', operation='set_mission', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ОТЛАДКА][SECURITY] событие разрешено политиками, выполняем
# [ОТЛАДКА][SECURITY] проверка события Event(source='control', destination='safety', operation='set_speed', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission'), SecurityPolicy(source='control', destination='safety', operation='set_speed')]
# [ОТЛАДКА][SECURITY] проверка события Event(source='control', destination='safety', operation='set_speed', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ОТЛАДКА][SECURITY] событие разрешено политиками, выполняем
# [ОТЛАДКА][SECURITY] проверка события Event(source='communication', destination='cargo', operation='release_cargo', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# PASSED
#
# ======================= 1 passed, 9 deselected in 0.02s ========================

# %% [markdown]
# В одном кодовом блоке ниже (или нескольких - как будет удобнее)  сделайте следующее
#
# 1. Измените реализацию монитора безопасности в части правил проверки передаваемых сообщений в мониторе безопасности
# 2. Измените параметры отправки сообщений между элементами бортовых систем (блоками 1-7), чтобы они всегда отправлялись в очередь монитора безопасности (отправитель и получатель при этом не меняются)
# 3. После всех изменений убедитесь в том, что машинка по-прежнему успешно выполняет маршрутное задание и доставляет груз
# 4. Дополнительные баллы принесут автоматические тесты правил безопасности в файле tests/module/test_security_monitor.py - можно проверить, что все новые политики работают как ожидаются, а недопустимые взаимодействия (т.е. таких стрелок нет на рис. 8) блокируются

# %%
# напишите свой код в этой ячейке, запустите машинку по маршруту, убедитесь, 
# что в конечной (и только в конечной!) точке CargoBay получает команду и успешно выполняет выгрузку

import math
from multiprocessing import Queue
from src.event_types import Event
from src.communication_gateway import BaseCommunicationGateway
from src.control_system import BaseControlSystem
from src.navigation_system import BaseNavigationSystem
from src.safety_block import BaseSafetyBlock
from src.config import LOG_ERROR, LOG_DEBUG, LOG_INFO, SERVOS_QUEUE_NAME, CARGO_BAY_QUEUE_NAME, CONTROL_SYSTEM_QUEUE_NAME, SAFETY_BLOCK_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME

class CommunicationGateway(BaseCommunicationGateway):
    """Класс для реализации логики взаимодействия с системой планирования заданий.
    Работает в отдельном процессе, поэтому создаётся как наследник класса Process.
    """
    def _send_mission_to_consumers(self):
        """Метод для отправки сообщения с маршрутным заданием в систему управления."""
        
        # Получаем имя очереди системы управления
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME 

        # Создаём событие с маршрутным заданием
        event_control = Event(
            source=BaseCommunicationGateway.event_source_name,
            destination=control_q_name,
            operation="set_mission",
            parameters=self._mission
        )
        event_safety = Event(
            source=BaseCommunicationGateway.event_source_name,
            destination=safety_q_name,
            operation="set_mission",
            parameters=self._mission
        )

        # Ищем в каталоге нужную очередь
        security_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)

        # Отправляем событие в найденную очередь
        security_q.put(event_control)
        security_q.put(event_safety)
        
class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def _send_speed_and_direction_to_consumers(self, speed, direction):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди

        # отправка сообщения с желаемой скоростью
        event_speed = Event(
            source=BaseControlSystem.event_source_name,
            destination=safety_q_name,
            operation="set_speed",
            parameters=speed
        )                   # замените на код создания сообщения со скоростью для приводов
                            # подсказка, требуемая операция - set_speed

        # отправка сообщения с желаемым направлением
        event_direction = Event(
            source=BaseControlSystem.event_source_name,
            destination=safety_q_name,
            operation="set_direction",
            parameters=direction
        )                       # замените на код создания сообщения с направлением для приводов
                                # подсказка, требуемая операция - set_direction

        security_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)

        security_q.put(event_speed)
        security_q.put(event_direction)   

    
    def _release_cargo(self):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME 
        
        event_release_cargo = Event(
            source=BaseControlSystem.event_source_name,
            destination=safety_q_name,
            operation="release_cargo",
            parameters=None
        )                      

        security_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)

        security_q.put(event_release_cargo)   


    def _lock_cargo(self):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME 
        
        event_lock_cargo = Event(
            source=BaseControlSystem.event_source_name,
            destination=safety_q_name,
            operation="lock_cargo",
            parameters=None
        )                      

        security_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)

        security_q.put(event_lock_cargo)    

class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):                              
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME # замените на правильное название очереди

        event_safety = Event(
            source=BaseNavigationSystem.event_source_name,
            destination=safety_q_name,
            operation="position_update",
            parameters=self._position           # Координаты текущего местоположения
        )                                       # замените на код создания сообщения с координатами для системы управления 
                                                # подсказка, требуемая операция - position_update

        event_control = Event(
            source=BaseNavigationSystem.event_source_name,
            destination=control_q_name,
            operation="position_update",
            parameters=self._position          
        )     
                                                
        security_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        
        security_q.put(event_safety)
        security_q.put(event_control)

class SafetyBlock(BaseSafetyBlock):
    """ Класс ограничений безопасности """

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"новые координаты: {direction}")
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")

        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, "Неизвестный маршрут или позиция! Остановка.")
            self._stop_the_car()
            return
        
        target_direction = self._calculate_bearing(self._position, self._route.next_point())
        tolerance = 1

        if (abs(target_direction - direction) > tolerance):
            self._log_message(LOG_ERROR, "Направление не совпадает с маршрутом! Остановка.")
            self._stop_the_car()
            return
        
        self._direction = direction    
        self._send_direction_to_consumers()

    def _calculate_bearing(self, start: GeoPoint, end: GeoPoint) -> float:
        if not start or not end:
            self._log_message(LOG_ERROR, "Не указана начальная или конечная точка для расчета направления! Остановка.")
            self._stop_the_car()
            return 0

        delta_longitude = end.longitude - start.longitude
        x = math.sin(math.radians(delta_longitude)) * \
            math.cos(math.radians(end.latitude))
        y = math.cos(math.radians(start.latitude)) * math.sin(math.radians(end.latitude)) - \
            math.sin(math.radians(start.latitude)) * math.cos(math.radians(end.latitude)) * \
            math.cos(math.radians(delta_longitude))

        initial_bearing_rad = math.atan2(x, y)

        # Преобразуем радианы в градусы
        initial_bearing_deg = math.degrees(initial_bearing_rad)

        # Нормализуем значение в диапазоне [0, 360]
        compass_bearing = (initial_bearing_deg + 360) % 360

        return compass_bearing

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        self._log_message(LOG_INFO, f"новая скорость: {speed}")
        self._log_message(LOG_INFO, f"текущая скорость: {self._speed}")

        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, "Неизвестный маршрут или позиция! Остановка.")
            self._stop_the_car()
            return 
        
        allowed_speed = self._route.calculate_speed()
        
        if speed > allowed_speed:
            self._log_message(LOG_ERROR, f"Скорость {speed} превышает лимит {allowed_speed}. Ограничиваем.")
            self._speed = allowed_speed
        else:
            self._speed = speed
        
        self._send_speed_to_consumers()

    def _stop_the_car(self):
        self._speed = 0
        self._direction = 0    
        
        self._send_speed_to_consumers()  
        self._send_direction_to_consumers()
        self._send_lock_cargo_to_consumers()

    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME

        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed)
        
        security_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)

        security_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем направление получателям")
        servos_q_name = SERVOS_QUEUE_NAME

        event_direction = Event(source=self.event_source_name,
                                destination=servos_q_name,
                                operation="set_direction",
                                parameters=self._direction)
        
        security_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)

        security_q.put(event_direction)

    def _lock_cargo(self, _):
        self._log_message(LOG_INFO, "Блокировка грузового отсека")
        self._send_lock_cargo_to_consumers()

    def _release_cargo(self, _):
        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, "Неизвестный маршрут или позиция! Остановка.")
            self._stop_the_car()
            return 

        if not self._route.route_finished:
            self._log_message(LOG_INFO, "Маршрут не завершён, выгрузка невозможна!")
            return
        
        self._send_release_cargo_to_consumers()
    

    def _send_lock_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду на блокировку грузового отсека")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="lock_cargo",
            parameters=None
        )
        
        security_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)

        security_q.put(event)

    def _send_release_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду на разблокировку грузового отсека")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="release_cargo",
            parameters=None
        )

        security_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)

        security_q.put(event)

# %%
# добавьте изменения сюда

from src.security_monitory import BaseSecurityMonitor
from src.security_policy_type import SecurityPolicy

from src.config import COMMUNICATION_GATEWAY_QUEUE_NAME, NAVIGATION_QUEUE_NAME, SAFETY_BLOCK_QUEUE_NAME, CONTROL_SYSTEM_QUEUE_NAME, LOG_DEBUG, LOG_ERROR, LOG_INFO
    
class SecurityMonitor(BaseSecurityMonitor):
    """ класс монитора безопасности """

    def __init__(self, queues_dir):
        super().__init__(queues_dir)
        self._init_set_security_policies()

    def _init_set_security_policies(self):
        """ инициализация политик безопасности """
        default_policies = [
            
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='set_mission'
            ),
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_mission'
            ),

            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_speed'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_direction'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='release_cargo'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='lock_cargo'
            ),

            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='position_update'
            ),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='position_update'
            ),

            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation='set_speed'
            ),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation='set_direction'
            ),
             SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation='lock_cargo'
            ),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation='release_cargo'
            )
        ]

        self.set_security_policies(policies=default_policies)        

    def set_security_policies(self, policies):
        """ установка новых политик безопасности """
        self._security_policies = policies
        self._log_message(
            LOG_INFO, f"изменение политик безопасности: {policies}")

    def _check_event(self, event: Event):
        """ проверка входящих событий """
        self._log_message(
            LOG_DEBUG, f"проверка события {event}, по умолчанию выполнение запрещено")

        authorized = False
        request = SecurityPolicy(
            source=event.source,
            destination=event.destination,
            operation=event.operation)

        if request in self._security_policies:
            self._log_message(
                LOG_DEBUG, "событие разрешено политиками, выполняем")
            authorized = True

        if authorized is False:
            self._log_message(LOG_ERROR, f"событие не разрешено политиками безопасности! {event}")
        return authorized

# %%
# создадим все остальные компоненты

communication_gateway = CommunicationGateway(queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)
navigation_system = NavigationSystem(queues_dir=queues_dir, log_level=LOG_ERROR)

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)

security = SecurityMonitor(queues_dir=queues_dir)

# соберём все компоненты для запуска
# в зависимости от наличия СУПА используем разный набор компонентов - с передачей телеметрии или без

system_components = SystemComponentsContainer(
components=[
        # вариант компонентов с передачей телеметрии в СУПА
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block,
        security
    ] if afcs_present else [
        # вариант компонентов для конфигурации без СУПА
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block,
        security
    ])

system_components.start()

# настройте этот параметр так, чтобы проверить работу ограничителя
sleep(170)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель
# [ИНФО][QUEUES] регистрируем очередь security
# [ИНФО][SECURITY] создан монитор безопасности
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission'), SecurityPolicy(source='communication', destination='safety', operation='set_mission'), SecurityPolicy(source='control', destination='safety', operation='set_speed'), SecurityPolicy(source='control', destination='safety', operation='set_direction'), SecurityPolicy(source='control', destination='safety', operation='release_cargo'), SecurityPolicy(source='control', destination='safety', operation='lock_cargo'), SecurityPolicy(source='navigation', destination='safety', operation='position_update'), SecurityPolicy(source='navigation', destination='control', operation='position_update'), SecurityPolicy(source='safety', destination='servos', operation='set_speed'), SecurityPolicy(source='safety', destination='servos', operation='set_direction'), SecurityPolicy(source='safety', destination='cargo', operation='lock_cargo'), SecurityPolicy(source='safety', destination='cargo', operation='release_cargo')]
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][CONTROL] старт системы управления[ИНФО][SAFETY] старт ограничителя
#
# [ИНФО][SECURITY] старт блока грузового отсека
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 21:24:33.305174
# [ИНФО][SAFETY] Блокировка грузового отсека
# [ИНФО][CONTROL] новая скорость 20 (была 0)
# [ИНФО][CONTROL] новое направление 253 (было 0)
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 0
# [ИНФО][SAFETY] новые координаты: 253.75928369921178
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.5808s N, 29 49m 38.514s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.75928369921178
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.5808s N, 29 49m 38.514s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.75928369921178
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.5808s N, 29 49m 38.514s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.75928369921178
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.5808s N, 29 49m 38.514s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7596574932637
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.5557s N, 29 49m 38.3426s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76004402761203
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.53059s N, 29 49m 38.1712s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.760443929294
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.50549s N, 29 49m 37.9998s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76085786814951
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.48039s N, 29 49m 37.8285s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7612802055091
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.45529s N, 29 49m 37.6571s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7617111553676
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.43018s N, 29 49m 37.4857s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76215093615698
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.40508s N, 29 49m 37.3143s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7625997704738
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.37998s N, 29 49m 37.1429s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7630580006832
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.35488s N, 29 49m 36.9715s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76352598756276
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.32978s N, 29 49m 36.8001s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76399562473463
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.30468s N, 29 49m 36.6288s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7644753095681
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.27959s N, 29 49m 36.4574s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7649654407722
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.25449s N, 29 49m 36.286s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76546661498452
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.22939s N, 29 49m 36.1146s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76597930157175
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.2043s N, 29 49m 35.9432s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76650400589804
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.1792s N, 29 49m 35.7718s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76704125801137
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.15411s N, 29 49m 35.6004s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76759162948747
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.12902s N, 29 49m 35.429s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76815572629033
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.10392s N, 29 49m 35.2577s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76873420023355
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.07883s N, 29 49m 35.0863s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7693277516887
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.05374s N, 29 49m 34.9149s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76993713033684
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.02865s N, 29 49m 34.7435s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77056314758656
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.00356s N, 29 49m 34.5721s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77120667256915
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.97848s N, 29 49m 34.4007s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7718686501834
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.95339s N, 29 49m 34.2293s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77255009839052
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.9283s N, 29 49m 34.0579s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77325212764
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.90322s N, 29 49m 33.8865s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77397593981442
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.87813s N, 29 49m 33.7151s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77472285049112
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.85305s N, 29 49m 33.5437s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77549429444983
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.82797s N, 29 49m 33.3723s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77629184431817
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.80289s N, 29 49m 33.2009s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77711723181062
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.77781s N, 29 49m 33.0295s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77797236221267
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.75273s N, 29 49m 32.8581s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77885934645423
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.72765s N, 29 49m 32.6867s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7797805230301
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.70258s N, 29 49m 32.5153s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.78073849688428
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.6775s N, 29 49m 32.3439s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.78173619163346
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.65243s N, 29 49m 32.1725s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.78277688117544
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.62735s N, 29 49m 32.0011s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7838642639337
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.60228s N, 29 49m 31.8297s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.78500253482966
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.57721s N, 29 49m 31.6583s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.78619647862593
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.55215s N, 29 49m 31.4869s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.78745158281515
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.52708s N, 29 49m 31.3155s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7887741831762
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.50202s N, 29 49m 31.1441s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.79017165217385
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.47695s N, 29 49m 30.9727s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7916526240055
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.45189s N, 29 49m 30.8013s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.79322731663845
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.42683s N, 29 49m 30.6299s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.79490791833143
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.40178s N, 29 49m 30.4585s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.79670913887765
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.37672s N, 29 49m 30.2871s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.79864894903739
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.35167s N, 29 49m 30.1157s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.8007496192635
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.32662s N, 29 49m 29.9442s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.80303916665355
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.30157s N, 29 49m 29.7728s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.80571658703354
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.27653s N, 29 49m 29.6014s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.80871049566153
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.25148s N, 29 49m 29.43s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.81210042890737
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.22644s N, 29 49m 29.2586s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.81599847699144
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.20141s N, 29 49m 29.0872s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.82054822518324
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.17637s N, 29 49m 28.9157s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.82598667133288
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.15134s N, 29 49m 28.7443s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.83269770781914
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.12632s N, 29 49m 28.5729s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.83935194048004
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.10631s N, 29 49m 28.4357s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.85021190111263
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.0813s N, 29 49m 28.2643s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.86631483947846
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.05629s N, 29 49m 28.0929s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 304 (было 253)
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.89450542231967
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.0313s N, 29 49m 27.9214s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] новое направление 306 (было 304)
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 304.22917748951943
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.00632s N, 29 49m 27.75s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 306.40165260912073
# [ИНФО][SAFETY] текущие координаты: 59 52m 7.98135s N, 29 49m 27.5785s E
# [ИНФО][CONTROL] новое направление 308 (было 306)
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 308.70741541999826
# [ИНФО][SAFETY] текущие координаты: 59 52m 7.95641s N, 29 49m 27.407s E
# [ИНФО][CONTROL] новое направление 311 (было 308)
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.1507304645798
# [ИНФО][SAFETY] текущие координаты: 59 52m 7.93151s N, 29 49m 27.2355s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.4092000065405
# [ИНФО][SAFETY] текущие координаты: 59 52m 7.98478s N, 29 49m 27.0919s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.56369095624876
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.04091s N, 29 49m 26.9526s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.5862169365022
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.09997s N, 29 49m 26.8181s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.594673312656
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.15934s N, 29 49m 26.6843s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.5934206135006
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.21889s N, 29 49m 26.5507s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.5902693627569
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.27847s N, 29 49m 26.4172s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.58590787195374
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.33805s N, 29 49m 26.2837s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.5808804870486
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.39764s N, 29 49m 26.1502s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.5751774992723
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.45722s N, 29 49m 26.0167s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.56870988551435
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.5168s N, 29 49m 25.8832s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.56127839127777
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.57637s N, 29 49m 25.7496s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.55257396449736
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.63593s N, 29 49m 25.6161s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.54210161541727
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.69549s N, 29 49m 25.4826s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.5290219121546
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.75504s N, 29 49m 25.349s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.51176434489406
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.81457s N, 29 49m 25.2154s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.48693275213384
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.8741s N, 29 49m 25.0818s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 311.4452573097842
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.93361s N, 29 49m 24.9482s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 60 (была 20)
# [ИНФО][CONTROL] новое направление 60 (было 311)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 60.23478161850903
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.9931s N, 29 49m 24.8145s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 60.743050084394895
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.05256s N, 29 49m 24.6808s E
# [ИНФО][CONTROL] новое направление 61 (было 60)
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.24806391792953
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.11197s N, 29 49m 24.547s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.27857236921483
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.24565s N, 29 49m 25.0118s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.29579993803958
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.37725s N, 29 49m 25.479s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.29862705452251
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.50678s N, 29 49m 25.9485s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.300666081548115
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.63618s N, 29 49m 26.4182s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.302272819065706
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.76551s N, 29 49m 26.8879s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.303888674817586
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.89483s N, 29 49m 27.3576s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.305542070114655
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.0241s N, 29 49m 27.8274s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.307252680671525
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.1534s N, 29 49m 28.2971s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.30902659018466
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.2827s N, 29 49m 28.7669s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.3108697214725
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.412s N, 29 49m 29.2366s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.31278815978408
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.5413s N, 29 49m 29.7064s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.31478876129063
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.6706s N, 29 49m 30.1762s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.31687932451666
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.7999s N, 29 49m 30.6459s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.31906880925624
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.9291s N, 29 49m 31.1157s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.32136757158662
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.0584s N, 29 49m 31.5855s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.323787672397884
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.1876s N, 29 49m 32.0554s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.32634327234797
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.3168s N, 29 49m 32.5252s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.329051142681465
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.4461s N, 29 49m 32.995s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.331931347759564
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.5753s N, 29 49m 33.4649s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.335008157675304
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.7045s N, 29 49m 33.9347s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.338311295302674
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.8337s N, 29 49m 34.4046s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.34187769270608
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.9629s N, 29 49m 34.8745s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.34575398871931
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.092s N, 29 49m 35.3444s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.35000020765034
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.2212s N, 29 49m 35.8143s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.35469533076645
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.3503s N, 29 49m 36.2842s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.36034543328117
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.4795s N, 29 49m 36.7542s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.366736518422044
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.6086s N, 29 49m 37.2241s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.374207276481684
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.7377s N, 29 49m 37.6941s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.38315808163338
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.8668s N, 29 49m 38.1641s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.39187224136299
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.97s N, 29 49m 38.5401s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.40543213320268
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.099s N, 29 49m 39.0101s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.42398080700616
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.2281s N, 29 49m 39.4802s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.45214490764715
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.357s N, 29 49m 39.9503s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.50511441230958
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.486s N, 29 49m 40.4205s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.65894832052703
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.6148s N, 29 49m 40.8907s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 90 (было 61)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 90.38104409635963
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7436s N, 29 49m 41.361s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 90.87991619540901
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.8723s N, 29 49m 41.8315s E
# [ИНФО][CONTROL] новое направление 91 (было 90)
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.39380642745402
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0008s N, 29 49m 42.3021s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.921751583846
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.1286s N, 29 49m 42.7735s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.95097514117026
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.1268s N, 29 49m 43.309s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.97170070945782
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.1227s N, 29 49m 43.8445s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98313100210885
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.1161s N, 29 49m 44.3799s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98442467492305
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.1071s N, 29 49m 44.9151s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98517030725696
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0979s N, 29 49m 45.4504s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98551120514185
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0887s N, 29 49m 45.9856s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98561990595385
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0794s N, 29 49m 46.5208s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98570232511997
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.07s N, 29 49m 47.056s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98576892672469
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0607s N, 29 49m 47.5912s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98582785975844
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0514s N, 29 49m 48.1265s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98588208380778
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.042s N, 29 49m 48.6617s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98593423587101
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0327s N, 29 49m 49.1969s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.9859843515344
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0234s N, 29 49m 49.7321s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98603239784035
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0141s N, 29 49m 50.2674s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98607826725276
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0047s N, 29 49m 50.8026s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98612184128001
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9954s N, 29 49m 51.3378s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98616298952174
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9861s N, 29 49m 51.873s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98620157140653
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9767s N, 29 49m 52.4082s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98623743082612
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9674s N, 29 49m 52.9435s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98627039902533
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9581s N, 29 49m 53.4787s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98630029052936
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9487s N, 29 49m 54.0139s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98632690251776
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9394s N, 29 49m 54.5491s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98635000965112
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9301s N, 29 49m 55.0844s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98636936421752
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9207s N, 29 49m 55.6196s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.986384689999
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9114s N, 29 49m 56.1548s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.9863956800449
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9021s N, 29 49m 56.69s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98640199214282
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.8927s N, 29 49m 57.2252s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.9864032392943
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.8834s N, 29 49m 57.7605s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98639898709706
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.8741s N, 29 49m 58.2957s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98638874057383
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.8647s N, 29 49m 58.8309s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98637193702984
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.8554s N, 29 49m 59.3661s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98634793105452
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.8461s N, 29 49m 59.9013s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98631597803433
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.8367s N, 29 50m 0.436569s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98627521060769
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.8274s N, 29 50m 0.97179s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98622461153371
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.8181s N, 29 50m 1.50701s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98616298032033
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.8087s N, 29 50m 2.04223s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98608888430664
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7994s N, 29 50m 2.57745s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98600059267233
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7901s N, 29 50m 3.11267s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.9858959955485
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7807s N, 29 50m 3.64789s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98577247320225
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7714s N, 29 50m 4.18312s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98562673587298
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7621s N, 29 50m 4.71834s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98549211969458
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7546s N, 29 50m 5.14651s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98529512763264
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7453s N, 29 50m 5.68173s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98506339382504
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7359s N, 29 50m 6.21696s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98478156759734
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7266s N, 29 50m 6.75218s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.9844145772027
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7173s N, 29 50m 7.2874s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98395425686994
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.708s N, 29 50m 7.82262s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98336059570795
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.6986s N, 29 50m 8.35784s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98256536510883
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.6893s N, 29 50m 8.89306s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.98144274247568
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.68s N, 29 50m 9.42828s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.97970860259488
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.6706s N, 29 50m 9.9635s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.97656354621915
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.6613s N, 29 50m 10.4987s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.96843367327801
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.652s N, 29 50m 11.0339s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 96 (было 91)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 96.9303969432766
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.6427s N, 29 50m 11.5692s E
# [ИНФО][CONTROL] новое направление 97 (было 96)
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.0224963069345
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.6334s N, 29 50m 12.1044s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.11813247826012
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.6241s N, 29 50m 12.6396s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.21760528196114
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.6149s N, 29 50m 13.1748s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22316545169252
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.5824s N, 29 50m 13.7065s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22709171959548
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.5495s N, 29 50m 14.238s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22921079949458
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.5161s N, 29 50m 14.7694s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22932859555198
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.4823s N, 29 50m 15.3007s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22932952688433
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.4484s N, 29 50m 15.832s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22924171323984
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.4145s N, 29 50m 16.3633s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22909966968211
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.3806s N, 29 50m 16.8946s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22894551356814
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.3467s N, 29 50m 17.4258s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22878319134963
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.3129s N, 29 50m 17.9571s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22861344077188
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.279s N, 29 50m 18.4884s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.2284360125247
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.2451s N, 29 50m 19.0197s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22825053282321
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.2112s N, 29 50m 19.551s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22805657016067
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.1773s N, 29 50m 20.0823s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22785365361119
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.1434s N, 29 50m 20.6135s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22764127144154
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.1096s N, 29 50m 21.1448s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.227418867192
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.0757s N, 29 50m 21.6761s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22718583321739
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.0418s N, 29 50m 22.2074s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22694150516628
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.0079s N, 29 50m 22.7387s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22668515464488
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.9741s N, 29 50m 23.27s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22641598027582
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.9402s N, 29 50m 23.8013s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22613309890778
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.9063s N, 29 50m 24.3325s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22583553126498
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.8724s N, 29 50m 24.8638s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22552219236951
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.8386s N, 29 50m 25.3951s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22519187075682
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.8047s N, 29 50m 25.9264s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22484321119629
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.7708s N, 29 50m 26.4577s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22447469047256
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.7369s N, 29 50m 26.989s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22408458567037
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.7031s N, 29 50m 27.5202s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22367094244078
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.6692s N, 29 50m 28.0515s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22323153218423
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.6354s N, 29 50m 28.5828s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22276378917707
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.6015s N, 29 50m 29.1141s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22226475265694
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.5676s N, 29 50m 29.6454s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.2217309732099
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.5338s N, 29 50m 30.1767s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22115840116652
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.4999s N, 29 50m 30.708s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.22054224147712
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.4661s N, 29 50m 31.2393s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.21987675997019
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.4322s N, 29 50m 31.7705s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.21930725724712
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.4051s N, 29 50m 32.1956s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.21854320605365
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.3713s N, 29 50m 32.7269s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.21770815956631
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.3374s N, 29 50m 33.2582s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.21677821654282
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.3036s N, 29 50m 33.7894s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.21574584956267
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.2698s N, 29 50m 34.3207s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.21451295282822
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.2359s N, 29 50m 34.852s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.21310317024171
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.2021s N, 29 50m 35.3833s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.21146773474811
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.1683s N, 29 50m 35.9146s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.20953424244601
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.1345s N, 29 50m 36.4459s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.2072026977084
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.1006s N, 29 50m 36.9772s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 97.20430167749635
# ...
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.3156s N, 29 50m 44.2383s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 115.91608006022955
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.1985s N, 29 50m 44.7205s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 115.91767618087619
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.081s N, 29 50m 45.2025s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 115.9164364185026
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.9634s N, 29 50m 45.6842s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 115.91432525423613
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.8458s N, 29 50m 46.1659s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 115.91148230576209
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.7281s N, 29 50m 46.6476s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 115.90804742913343
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.6104s N, 29 50m 47.1293s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 115.90411306435055
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.4927s N, 29 50m 47.6109s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 115.89961958197398
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.375s N, 29 50m 48.0926s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 115.89446754055962
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.2573s N, 29 50m 48.5743s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 115.8884942279015
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.1397s N, 29 50m 49.056s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 115.88143783256982
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.022s N, 29 50m 49.5377s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 115.87367799307162
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.90445s N, 29 50m 50.0195s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 115.86416276866737
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.78688s N, 29 50m 50.5013s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 115.85196298520674
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.66934s N, 29 50m 50.9831s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 115.8349792237263
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.55183s N, 29 50m 51.4649s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 115.80817504130795
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.43436s N, 29 50m 51.9468s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 115.7537097925815
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.31695s N, 29 50m 52.4287s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 43 (было 115)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 43.068669228621616
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.1996s N, 29 50m 52.9107s E
# [ИНФО][CONTROL] новое направление 40 (было 43)
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 40.07542463908669
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.08237s N, 29 50m 53.3928s E
# [ИНФО][CONTROL] новое направление 37 (было 40)
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 37.00137809494527
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.96537s N, 29 50m 53.8752s E
# [ИНФО][CONTROL] новое направление 36 (было 37)
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.64942837951503
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.16208s N, 29 50m 54.2409s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.43936937571675
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.36813s N, 29 50m 54.5856s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.40524367968334
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.58318s N, 29 50m 54.9079s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.39127035899594
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.79922s N, 29 50m 55.2276s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.39122233175652
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.0158s N, 29 50m 55.5457s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.39398715612498
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.2326s N, 29 50m 55.8635s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.39850709155775
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.4493s N, 29 50m 56.1812s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.40275552638252
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.6227s N, 29 50m 56.4354s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.408792159012535
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.8395s N, 29 50m 56.7532s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.41573378596172
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.0562s N, 29 50m 57.0709s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.423991497258385
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.273s N, 29 50m 57.3888s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.43391025852338
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.4897s N, 29 50m 57.7066s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.44626482477645
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.7064s N, 29 50m 58.0245s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.46246032826855
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.9231s N, 29 50m 58.3425s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.48551807609101
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.1397s N, 29 50m 58.6606s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.52345454517882
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.3563s N, 29 50m 58.9787s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 36.608536966639804
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.5729s N, 29 50m 59.297s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 20 (была 60)
# [ИНФО][CONTROL] новое направление 346 (было 36)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 346.5688764832496
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.7894s N, 29 50m 59.6154s E
# [ИНФО][CONTROL] новое направление 339 (было 346)
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 339.9195176403978
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.0059s N, 29 50m 59.9339s E
# [ИНФО][CONTROL] новое направление 332 (было 339)
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 332.06909647135615
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.2223s N, 29 51m 0.252578s E
# [ИНФО][CONTROL] новое направление 323 (было 332)
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 323.0382496316605
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.4384s N, 29 51m 0.571945s E
# [ИНФО][CONTROL] новое направление 321 (было 323)
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 321.63598349419004
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.5257s N, 29 51m 0.530481s E
# [ИНФО][CONTROL] новое направление 320 (было 321)
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 320.4655757687534
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.61s N, 29 51m 0.46919s E
# [ИНФО][CONTROL] новое направление 319 (было 320)
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 319.6629951134124
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.6893s N, 29 51m 0.385573s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 319.4080249989669
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.761s N, 29 51m 0.278235s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 319.2247909216384
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.8314s N, 29 51m 0.167439s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 319.1119093709628
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9006s N, 29 51m 0.0538076s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 319.05437460231826
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9691s N, 29 50m 59.9383s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 319.01169142969695
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0372s N, 29 50m 59.8221s E
# [ИНФО][CONTROL] новое направление 318 (было 319)
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 318.9806332939499
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.1052s N, 29 50m 59.7055s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 318.9564195622933
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.1731s N, 29 50m 59.5887s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 318.933627278113
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.2409s N, 29 50m 59.4717s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 318.910302722006
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.3086s N, 29 50m 59.3546s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 318.8834531984537
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.3763s N, 29 50m 59.2374s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 318.8479815244909
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.444s N, 29 50m 59.1202s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 318.7925983863628
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.5117s N, 29 50m 59.0029s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 333 (было 318)
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 333.350557878372
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.5793s N, 29 50m 58.8856s E
# [ИНФО][CONTROL] новое направление 334 (было 333)
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][CONTROL] новое направление 335 (было 334)[ИНФО][SAFETY] новые координаты: 334.3888290269359
#
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.647s N, 29 50m 58.7682s E
# [ИНФО][CONTROL] новое направление 336 (было 335)
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 335.586349309052
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.7146s N, 29 50m 58.6507s E
# [ИНФО][CONTROL] новое направление 337 (было 336)[ИНФО][SAFETY] новая скорость: 20
#
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 336.9822892145197
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.7821s N, 29 50m 58.5331s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 337.31397287603744
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.8623s N, 29 50m 58.4531s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 337.6076885381732
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.9432s N, 29 50m 58.3759s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 337.8325087226559
# [ИНФО][SAFETY] текущие координаты: 59 52m 15.025s N, 29 50m 58.3021s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 337.93666511918224
# [ИНФО][SAFETY] текущие координаты: 59 52m 15.1076s N, 29 50m 58.2323s E
# [ИНФО][CONTROL] новое направление 338 (было 337)
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 338.02280961254377
# [ИНФО][SAFETY] текущие координаты: 59 52m 15.1904s N, 29 50m 58.1635s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 338.08817558087526
# [ИНФО][SAFETY] текущие координаты: 59 52m 15.2734s N, 29 50m 58.0955s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 338.11254693545635
# [ИНФО][SAFETY] текущие координаты: 59 52m 15.3566s N, 29 50m 58.0284s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 338.12717337806737
# [ИНФО][SAFETY] текущие координаты: 59 52m 15.4398s N, 29 50m 57.9616s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 338.12905315229665
# [ИНФО][SAFETY] текущие координаты: 59 52m 15.5231s N, 29 50m 57.895s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 338.1196675774997
# [ИНФО][SAFETY] текущие координаты: 59 52m 15.6064s N, 29 50m 57.8284s E
# [ИНФО][CONTROL] маршрут пройден, текущее время 21:27:11.431573
# [ИНФО][CONTROL] новая скорость 0.0 (была 20)
# [ИНФО][CONTROL] новое направление 0 (было 338)
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] новая скорость: 0.0
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 0.0
# [ИНФО][SAFETY] текущие координаты: 59 52m 15.6897s N, 29 50m 57.7619s E
# [ОШИБКА][SAFETY] Не указана начальная или конечная точка для расчета направления! Остановка.
# [ИНФО][CARGO] выгрузка
# [ИНФО][CARGO] груз оставлен
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден

# %% [markdown]
# На этом модуль 3 завершён!
#
# Если у вас всё получилось, то вы создали защищённую автономную машинку - ещё уже не так-то просто использовать для нанесения критического ущерба людям и имуществу, потому что самые критические режимы проверяются вашим Ограничителем, а если вы ещё и внедрили Монитор Безопасности, то теперь злоумышленнику гораздо сложнее атаковать внутренние блоки, даже если он смог проникнуть в какую-то бортовую систему или внедрить вредоносный код.
#
# Осталось проверить эффективность получившейся защиты на полной трассе - в этом и заключается модуль 4 задания, для перехода к которому нужно открыть блокнот с именем cyberimmunity--autonomous-car-m4. Успеха!
