# %% [markdown]
# # Безопасное обновление системы
# ## Организация обновления через канал связи с удалённым сервером
#
# Этот ноутбук реализует систему безопасного обновления с использованием Монитора Безопасности и разделённой системы управления, как показано в диаграмме.
#
# Основные этапы:
# - Запрос обновления прошивки.
# - Сохранение файла с новой версией прошивки в локальном хранилище.
# - Создание цифровой подписи.
# - Проверка цифровой подписи и использование новой версии прошивки.
# - Запуск системы с новой версией прошивки.

# %% [markdown]
# ### Создаем WPL файл с моим маршрутом

# %%
wpl_file_content =  """QGC WPL 110
0	1	0	16	0	5	0	0	59.869328 29.827365	0	1
1	0	3	16	0	5	0	0	59.868883 29.824322	0	1
2	0	3	16	0	5	0	0	59.869184 29.823516	0	1
3	0	3	16	0	5	0	0	59.870481 29.828145	0	1
4	0	3	16	0	5	0	0	59.870456 29.836566 0	1
5	0	3	16	0	5	0	0	59.869963 29.844628 0	1
6	0	3	16	0	5	0	0	59.869206 29.848098	0	1
7	0	3	16	0	5	0	0	59.870235 29.849917	0	1
8	0	3	16	0	5	0	0	59.870743 29.849644	0	1
9	0	3	16	0	5	0	0	59.871044 29.849363	0	1
"""

from src.mission_type import GeoSpecificSpeedLimit

speed_limits = [
    GeoSpecificSpeedLimit(0, 20),
    GeoSpecificSpeedLimit(2, 60),
    GeoSpecificSpeedLimit(7, 20),
]

wpl_file = "secure_update/secure_update.wpl"
with open(wpl_file, "w") as f:
    f.write(wpl_file_content)

afcs_present = True

car_id = "secure_update"

# %% [markdown]
# ### Собираем внешние компоненты программы (остались без измненений из предыдущих модулей)

# %%
import math

from geopy import Point as GeoPoint
from multiprocessing import Queue
from src.event_types import Event
from src.communication_gateway import BaseCommunicationGateway
from src.navigation_system import BaseNavigationSystem
from src.safety_block import BaseSafetyBlock
from src.config import LOG_ERROR, LOG_DEBUG, LOG_INFO, SERVOS_QUEUE_NAME, CARGO_BAY_QUEUE_NAME, CONTROL_SYSTEM_QUEUE_NAME, SAFETY_BLOCK_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME

class CommunicationGateway(BaseCommunicationGateway):
    """Класс для реализации логики взаимодействия с системой планирования заданий.
    Работает в отдельном процессе, поэтому создаётся как наследник класса Process.
    """
    def _send_mission_to_consumers(self):
        """Метод для отправки сообщения с маршрутным заданием в систему управления."""
        
        # Получаем имя очереди системы управления
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME 

        # Создаём событие с маршрутным заданием
        event_control = Event(
            source=BaseCommunicationGateway.event_source_name,
            destination=control_q_name,
            operation="set_mission",
            parameters=self._mission
        )
        event_safety = Event(
            source=BaseCommunicationGateway.event_source_name,
            destination=safety_q_name,
            operation="set_mission",
            parameters=self._mission
        )

        # Ищем в каталоге нужную очередь
        security_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)

        # Отправляем событие в найденную очередь
        security_q.put(event_control)
        security_q.put(event_safety)  

class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):                              
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME # замените на правильное название очереди

        event_safety = Event(
            source=BaseNavigationSystem.event_source_name,
            destination=safety_q_name,
            operation="position_update",
            parameters=self._position           # Координаты текущего местоположения
        )                                       # замените на код создания сообщения с координатами для системы управления 
                                                # подсказка, требуемая операция - position_update

        event_control = Event(
            source=BaseNavigationSystem.event_source_name,
            destination=control_q_name,
            operation="position_update",
            parameters=self._position          
        )     
                                                
        security_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        
        security_q.put(event_safety)
        security_q.put(event_control)

class SafetyBlock(BaseSafetyBlock):
    """ Класс ограничений безопасности """

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"новые координаты: {direction}")
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")

        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, "Неизвестный маршрут или позиция! Остановка.")
            self._stop_the_car()
            return
        
        target_direction = self._calculate_bearing(self._position, self._route.next_point())
        tolerance = 1

        if (abs(target_direction - direction) > tolerance):
            self._log_message(LOG_ERROR, "Направление не совпадает с маршрутом! Остановка.")
            self._stop_the_car()
            return
        
        self._direction = direction    
        self._send_direction_to_consumers()

    def _calculate_bearing(self, start: GeoPoint, end: GeoPoint) -> float:
        if not start or not end:
            self._log_message(LOG_ERROR, "Не указана начальная или конечная точка для расчета направления! Остановка.")
            self._stop_the_car()
            return 0

        delta_longitude = end.longitude - start.longitude
        x = math.sin(math.radians(delta_longitude)) * \
            math.cos(math.radians(end.latitude))
        y = math.cos(math.radians(start.latitude)) * math.sin(math.radians(end.latitude)) - \
            math.sin(math.radians(start.latitude)) * math.cos(math.radians(end.latitude)) * \
            math.cos(math.radians(delta_longitude))

        initial_bearing_rad = math.atan2(x, y)

        # Преобразуем радианы в градусы
        initial_bearing_deg = math.degrees(initial_bearing_rad)

        # Нормализуем значение в диапазоне [0, 360]
        compass_bearing = (initial_bearing_deg + 360) % 360

        return compass_bearing

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        self._log_message(LOG_INFO, f"новая скорость: {speed}")
        self._log_message(LOG_INFO, f"текущая скорость: {self._speed}")

        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, "Неизвестный маршрут или позиция! Остановка.")
            self._stop_the_car()
            return 
        
        allowed_speed = self._route.calculate_speed()
        
        if speed > allowed_speed:
            self._log_message(LOG_ERROR, f"Скорость {speed} превышает лимит {allowed_speed}. Ограничиваем.")
            self._speed = allowed_speed
        else:
            self._speed = speed
        
        self._send_speed_to_consumers()

    def _stop_the_car(self):
        self._speed = 0
        self._direction = 0    
        
        self._send_speed_to_consumers()  
        self._send_direction_to_consumers()
        self._send_lock_cargo_to_consumers()

    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME

        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed)
        
        security_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)

        security_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем направление получателям")
        servos_q_name = SERVOS_QUEUE_NAME

        event_direction = Event(source=self.event_source_name,
                                destination=servos_q_name,
                                operation="set_direction",
                                parameters=self._direction)
        
        security_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)

        security_q.put(event_direction)

    def _lock_cargo(self, _):
        self._log_message(LOG_INFO, "Блокировка грузового отсека")
        self._send_lock_cargo_to_consumers()

    def _release_cargo(self, _):
        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, "Неизвестный маршрут или позиция! Остановка.")
            self._stop_the_car()
            return 

        if not self._route.route_finished:
            self._log_message(LOG_INFO, "Маршрут не завершён, выгрузка невозможна!")
            return
        
        self._send_release_cargo_to_consumers()
    

    def _send_lock_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду на блокировку грузового отсека")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="lock_cargo",
            parameters=None
        )
        
        security_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)

        security_q.put(event)

    def _send_release_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду на разблокировку грузового отсека")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="release_cargo",
            parameters=None
        )

        security_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)

        security_q.put(event)

# %% [markdown]
# ### Собираем новый класс `ControlSystem` исполняющий код из обновляемого скрипта `control_system_impl.py`

# %%
from src.control_system import BaseControlSystem
import importlib.util
import sys
import os

class ControlSystem(BaseControlSystem):

    def __init__(self, queues_dir, log_level):
        super().__init__(queues_dir)

        self.control_system_instance = None
        self.queues_dir = queues_dir
        self.log_level = log_level
        self.impl_class_name = 'ControlSystemImpl'

        self._refresh_control_system_script(script_path='./secure_update/executable/control_system_impl.py')
    
    def _refresh_control_system_script(self, script_path):
        # Проверяем что файлс со скриптом существует
        if not os.path.exists(script_path):
            raise FileNotFoundError(f"{script_path} does not exist")

        # Загружаем новый исполняемый модуль из скрипта
        spec = importlib.util.spec_from_file_location(self.impl_class_name, script_path)
        module = importlib.util.module_from_spec(spec)
        sys.modules[self.impl_class_name] = module
        spec.loader.exec_module(module)
        control_system_class = getattr(module, self.impl_class_name, None)

        # Проверяем что требуемый класс найден и создаем его экземляр
        if control_system_class is None:
            raise ImportError(f'{self.impl_class_name} class not found.')

        control_system_instance = control_system_class()

        if not hasattr(control_system_instance, '_send_speed_and_direction_to_consumers'):
            raise ImportError(f'{self.impl_class_name} class does not have _send_speed_and_direction_to_consumers method.')
        
        if not hasattr(control_system_instance, '_release_cargo'):
            raise ImportError(f'{self.impl_class_name} class does not have _release_cargo method.')
        
        if not hasattr(control_system_instance, '_lock_cargo'):
            raise ImportError(f'{self.impl_class_name} class does not have _lock_cargo method.')
        
        self.control_system_instance = control_system_instance

    def _send_speed_and_direction_to_consumers(self, speed, direction):
       self.control_system_instance._send_speed_and_direction_to_consumers(speed, direction, self._queues_dir)
    
    def _release_cargo(self):
       self.control_system_instance._release_cargo(self._queues_dir)

    def _lock_cargo(self):
       self.control_system_instance._lock_cargo(self._queues_dir)
    
    def _refresh(self, script_name):
        self._refresh_control_system_script(f'./secure_update/executable/{script_name}')

# %% [markdown]
# ### Собираем `SecurityMonitor` с политиками общения между новыми компонентами

# %%
from src.security_monitory import BaseSecurityMonitor
from src.security_policy_type import SecurityPolicy

from src.config import COMMUNICATION_GATEWAY_QUEUE_NAME, NAVIGATION_QUEUE_NAME, SAFETY_BLOCK_QUEUE_NAME, CONTROL_SYSTEM_QUEUE_NAME, LOG_DEBUG, LOG_ERROR, LOG_INFO

# Очереди для новых компонентов
from secure_update.config import UPDATE_MANAGER_QUEUE_NAME, UPDATE_VARIFIER_QUEUE_NAME, UPDATER_QUEUE_NAME, USER_REQUEST_QUEUE_NAME
    
class SecurityMonitor(BaseSecurityMonitor):
    """ класс монитора безопасности """

    def __init__(self, queues_dir):
        super().__init__(queues_dir)
        self._init_set_security_policies()

    def _init_set_security_policies(self):
        """ инициализация политик безопасности """
        default_policies = [

            # Политики для новых компонентов
             SecurityPolicy(
                source=USER_REQUEST_QUEUE_NAME,
                destination=UPDATE_MANAGER_QUEUE_NAME,
                operation='update_system'
            ),
            SecurityPolicy(
                source=UPDATE_MANAGER_QUEUE_NAME,
                destination=UPDATE_VARIFIER_QUEUE_NAME,
                operation='sign_srcipt'
            ),
            SecurityPolicy(
                source=UPDATE_VARIFIER_QUEUE_NAME,
                destination=UPDATE_MANAGER_QUEUE_NAME,
                operation='sign_is_done'
            ),
            SecurityPolicy(
                source=UPDATE_MANAGER_QUEUE_NAME,
                destination=UPDATER_QUEUE_NAME,
                operation='update_srcipt'
            ),
            SecurityPolicy(
                source=UPDATER_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='refresh_script'
            ),

            # Политики для старых компонентов (без изменений)
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='set_mission'
            ),
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_mission'
            ),

            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_speed'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_direction'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='release_cargo'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='lock_cargo'
            ),

            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='position_update'
            ),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='position_update'
            ),

            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation='set_speed'
            ),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation='set_direction'
            ),
             SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation='lock_cargo'
            ),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation='release_cargo'
            )
        ]

        self.set_security_policies(policies=default_policies)        

    def set_security_policies(self, policies):
        """ установка новых политик безопасности """
        self._security_policies = policies
        self._log_message(
            LOG_INFO, f"изменение политик безопасности: {policies}")

    def _check_event(self, event: Event):
        """ проверка входящих событий """
        self._log_message(
            LOG_DEBUG, f"проверка события {event}, по умолчанию выполнение запрещено")

        authorized = False
        request = SecurityPolicy(
            source=event.source,
            destination=event.destination,
            operation=event.operation)

        if request in self._security_policies:
            self._log_message(
                LOG_DEBUG, "событие разрешено политиками, выполняем")
            authorized = True

        if authorized is False:
            self._log_message(LOG_ERROR, f"событие не разрешено политиками безопасности! {event}")
        return authorized

# %% [markdown]
# ### Создадим компоненты, которые будут обновлять версию программы

# %% [markdown]
# Базовый класс, от которого будем наследовать процессы

# %%
import datetime

from abc import abstractmethod
from multiprocessing import Queue, Process
from queue import Empty
from time import sleep
from src.queues_dir import QueuesDirectory
from src.event_types import Event
from src.config import DEFAULT_LOG_LEVEL, LOG_INFO, CRITICALITY_STR

class BaseProcess(Process):
    """ базовый класс для создания процессов """

    def __init__(self, queues_dir: QueuesDirectory, log_prefix, events_q_name, process_name, log_level=DEFAULT_LOG_LEVEL):
        # вызываем конструктор базового класса
        super().__init__()
        self._log_level = log_level
        self._queues_dir = queues_dir
        self._log_prefix = log_prefix
        self._process_name = process_name

        # создаём очередь для сообщений на обработку
        self._events_q = Queue()
        self._events_q_name = events_q_name

        self._queues_dir.register(
            queue=self._events_q, name=self._events_q_name)

        # инициализируем интервал обновления
        self._recalc_interval_sec = 0.1
        self._quit = False
      
        self._log_message(LOG_INFO, f'создана {self._process_name}')

    def _log_message(self, criticality: int, message: str):
        """_log_message печатает сообщение заданного уровня критичности

        Args:
            criticality (int): уровень критичности
            message (str): текст сообщения
        """
        if criticality <= self._log_level:
            print(f"[{CRITICALITY_STR[criticality]}]{self._log_prefix} {message}")

    def _check_events_q(self):
        """_check_events_q
        проверяет входящие события до их полного исчерпания
        """

        while True:
            try:
                event: Event = self._events_q.get_nowait()
                if not isinstance(event, Event):
                    return
                self._process_event(event)
            except Empty:
                break

    def run(self):
        self._log_message(LOG_INFO, f"старт {self._process_name}")

        while self._quit is False:
            sleep(self._recalc_interval_sec)
            try:
                self._check_events_q()
            except Exception as e:
                self._log_message(LOG_ERROR, f"ошибка {self._process_name}: {e}")

    @abstractmethod
    def _process_event(self, event: Event):
        pass

# %% [markdown]
# Процесс, имитирующий действия пользователя
#
# Запросы от пользователя настроены следующим образом:
# 1. Спустя 5 секунд после запуска, пользователь отдает команду на обновление на вредоносную версию программы (наша система должна отбить атаку)
# 2. Спустя еще 5 секунд, пользователь отдает команду на обновление на допустимую версию программы (наша система должна успешно обновиться)

# %%
import datetime

from time import sleep
from abc import abstractmethod
from multiprocessing import Queue, Process
from queue import Empty
from time import sleep
from src.queues_dir import QueuesDirectory
from src.event_types import Event
from src.config import DEFAULT_LOG_LEVEL, LOG_INFO
from secure_update.config import UPDATE_MANAGER_QUEUE_NAME, USER_REQUEST_QUEUE_NAME

class User(BaseProcess):
    """ класс, имитирующий запросы от пользователя """

    def __init__(self, queues_dir: QueuesDirectory, log_level=DEFAULT_LOG_LEVEL):
        super().__init__(queues_dir=queues_dir, log_prefix="[USER]", events_q_name=USER_REQUEST_QUEUE_NAME, process_name="пользователь", log_level=log_level)
    
    def run(self):
        self._log_message(LOG_INFO, f"старт {self._process_name}")

        # сначала просим обновиться до вредоносной версии программы
        sleep(5)
        self._make_update_request("bad_script.py")

        # потом просим обновиться до нормальной версии программы
        sleep(5)
        self._make_update_request("good_script.py")

            
    def _make_update_request(self, script_name):
        update_manager_q_name = UPDATE_MANAGER_QUEUE_NAME 
        
        event_update = Event(
            source=self._events_q_name,
            destination=update_manager_q_name,
            operation="update_system",
            parameters=script_name
        )                      

        update_manager_q: Queue = self._queues_dir.get_queue(update_manager_q_name)

        update_manager_q.put(event_update)   
        
        self._log_message(LOG_INFO, f"отправил запрос на обновление программы: {script_name}")

# %% [markdown]
# Верификатор проверяет хэш файлов на обновление и подписывает их в случае, если файл на обновление допустимый

# %%
import datetime
import os
import shutil
from Crypto.Signature import pkcs1_15
from Crypto.Hash import SHA256
from Crypto.PublicKey import RSA

from abc import abstractmethod
from multiprocessing import Queue, Process
from queue import Empty
from time import sleep
from src.queues_dir import QueuesDirectory
from src.event_types import Event
from src.config import DEFAULT_LOG_LEVEL, LOG_INFO
from secure_update.config import UPDATE_MANAGER_QUEUE_NAME, UPDATE_VARIFIER_QUEUE_NAME

class Verifier(BaseProcess):
    """ базовый класс для верификации файлов с обновлениями """

    def __init__(self, queues_dir: QueuesDirectory, files_hash_map, log_level=DEFAULT_LOG_LEVEL):
        super().__init__(queues_dir=queues_dir, log_prefix="[VERIFIER]", events_q_name=UPDATE_VARIFIER_QUEUE_NAME, process_name="верификатор", log_level=log_level)
        self._files_hash_map = files_hash_map

        self._keys_folder = "./secure_update"
        if not (os.path.exists(f'{self._keys_folder}/private.pem') and os.path.exists(self._keys_folder)):
            self._generate_keys()

    def _process_event(self, event: Event):
        if event.operation == 'sign_srcipt':
            script_file_name = event.parameters
            self._verify_file(script_file_name)
            self._make_verifier_response(script_file_name)

    def _make_verifier_response(self, script_name):
        update_manager_q_name = UPDATE_MANAGER_QUEUE_NAME 
        
        event_update = Event(
            source=self._events_q_name,
            destination=update_manager_q_name,
            operation="sign_is_done",
            parameters=script_name
        )                      

        update_manager_q: Queue = self._queues_dir.get_queue(update_manager_q_name)

        update_manager_q.put(event_update)   
        
        self._log_message(LOG_INFO, f"отправил успешный ответ на подпись: {script_name}") 
        
    def _verify_file(self, file_name):
        source_dir = "./secure_update/destination"

        # Полные пути к файлу
        source_file_path = os.path.join(source_dir, file_name)
        source_sign_path = os.path.join(source_dir, f'{file_name}.sign')
        
        # Проверка, существует ли файл в исходной директории
        if not os.path.exists(source_file_path):
            raise ImportError(f"Файл {source_file_path} не найден.")

        file_hash = self._calculate_sha256(source_file_path)
        self._log_message(LOG_INFO, f"хеш файла {file_name}: {file_hash.hexdigest()}")
        if self._files_hash_map[file_name] != file_hash.hexdigest():
            raise ImportError(f"Файл {source_file_path} не верифицирован.")

        self._sign_file(source_file_path, source_sign_path, file_hash)
        self._log_message(LOG_INFO, f"файл {file_name} успешно провалидирован.")

    def _calculate_sha256(self, file_path):
        with open(file_path, "rb") as f:
            file_data = f.read()
        return SHA256.new(file_data)

    def _sign_file(self, file_path, signature_path, file_hash):
        # Load the private key
        with open(f'{self._keys_folder}/private.pem', "rb") as f:
            private_key = RSA.import_key(f.read())

        # Create a signature
        signature = pkcs1_15.new(private_key).sign(file_hash)

        # Save the signature to a file
        with open(signature_path, "wb") as f:
            f.write(signature)

        self._log_message(LOG_INFO, f"подпись сохранена в {signature_path}.")

    def _generate_keys(self):
        key = RSA.generate(2048)
        private_key = key.export_key()
        with open(f'{self._keys_folder}/private.pem', "wb") as f:
            f.write(private_key)

        public_key = key.publickey().export_key()
        with open(f'{self._keys_folder}/public.pem', "wb") as f:
            f.write(public_key)

# %% [markdown]
# Модуль обновления проверяет, что новый файл с обновлением подписан верификатором и запускает процесс обновления внутри контейнера

# %%
import datetime
import os
import shutil
from Crypto.Signature import pkcs1_15
from Crypto.Hash import SHA256
from Crypto.PublicKey import RSA

from abc import abstractmethod
from multiprocessing import Queue, Process
from queue import Empty
from time import sleep
from src.queues_dir import QueuesDirectory
from src.event_types import Event
from src.config import DEFAULT_LOG_LEVEL, LOG_INFO, CONTROL_SYSTEM_QUEUE_NAME
from secure_update.config import UPDATER_QUEUE_NAME

class Updater(BaseProcess):
    """ базовый класс для загрузки файлов с обновлениями """

    def __init__(self, queues_dir: QueuesDirectory, log_level=DEFAULT_LOG_LEVEL):
        super().__init__(queues_dir=queues_dir, log_prefix="[UPDATER]", events_q_name=UPDATER_QUEUE_NAME, process_name="модуль обновления", log_level=log_level)
        self._keys_folder = "./secure_update"

    def _process_event(self, event: Event):
        if event.operation == 'update_srcipt':
            script_file_name = event.parameters
            self._verify_signature(script_file_name)
            self._download_file(script_file_name)
            self._make_updater_response(script_file_name)

    def _make_updater_response(self, script_name):
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME 
        
        event_update = Event(
            source=self._events_q_name,
            destination=control_q_name,
            operation="refresh_script",
            parameters=script_name
        )                      

        control_q: Queue = self._queues_dir.get_queue(control_q_name)

        control_q.put(event_update)   
        
        self._log_message(LOG_INFO, f"отправил запрос на использование новой версии программы: {script_name}") 

    def _verify_signature(self, file_name):
        file_path = f'./secure_update/destination/{file_name}'
        signature_path = f'./secure_update/destination/{file_name}.sign'
        public_key_path = f'{self._keys_folder}/public.pem'

        # Читаем оригинальный файл
        if not os.path.exists(file_path):
            raise ImportError(f"Файл {file_path} не найден.")
        with open(file_path, "rb") as f:
            file_data = f.read()
        
        # Создаем хеш от файла
        hash_obj = SHA256.new(file_data)
        
        # Загружаем открытую часть ключа
        if not os.path.exists(public_key_path):
            raise ImportError(f"Ключ {public_key_path} не найден.")
        with open(public_key_path, "rb") as f:
            public_key = RSA.import_key(f.read())
        
        # Читаем подпись
        if not os.path.exists(signature_path):
            raise ImportError(f"Подпись {signature_path} не найдена.")
        with open(signature_path, "rb") as f:
            signature = f.read()
    
        pkcs1_15.new(public_key).verify(hash_obj, signature)
        self._log_message(LOG_INFO, f"подпись файла {file_name} успешно проверена.")

    def _download_file(self, file_name):
        source_dir = "./secure_update/destination"
        destination_dir = "./secure_update/executable"
        
        # Полные пути к файлу
        source_file_path = os.path.join(source_dir, file_name)
        destination_file_path = os.path.join(destination_dir, file_name)
        
        # Проверка, существует ли файл в исходной директории
        if not os.path.exists(source_file_path):
            raise ImportError(f"Файл {source_file_path} не найден.")

        # Перемещаем файл в директорию назначения
        shutil.copy2(source_file_path, destination_file_path)
        self._log_message(LOG_INFO, f"файл {file_name} успешно перемещен в {destination_dir}.")

# %% [markdown]
# Менеджер обновлений инициирует процесс обновления на уровне всей системы

# %%
import datetime
import os
import shutil

from abc import abstractmethod
from multiprocessing import Queue, Process
from queue import Empty
from time import sleep
from src.queues_dir import QueuesDirectory
from src.event_types import Event
from src.config import DEFAULT_LOG_LEVEL, LOG_INFO
from secure_update.config import UPDATE_MANAGER_QUEUE_NAME, UPDATE_VARIFIER_QUEUE_NAME, UPDATER_QUEUE_NAME

class UpdateManager(BaseProcess):
    """ базовый класс для запуска процесса обновления"""

    def __init__(self, queues_dir: QueuesDirectory, log_level=DEFAULT_LOG_LEVEL):
        super().__init__(queues_dir=queues_dir, log_prefix="[UPDATE_MANAGER]", events_q_name=UPDATE_MANAGER_QUEUE_NAME, process_name="менеджер обновлений", log_level=log_level)
    
    def _process_event(self, event: Event):
        if event.operation == 'update_system':
            script_file_name = event.parameters
            self._download_file(script_file_name)
            self._make_verifier_request(script_file_name)
        elif event.operation == 'sign_is_done':
            script_file_name = event.parameters
            self._make_updater_request(script_file_name)
    
    def _download_file(self, file_name):
        source_dir = "./secure_update/source"
        destination_dir = "./secure_update/destination"
        
        # Полные пути к файлу
        source_file_path = os.path.join(source_dir, file_name)
        destination_file_path = os.path.join(destination_dir, file_name)
        
        # Проверка, существует ли файл в исходной директории
        if not os.path.exists(source_file_path):
            raise ImportError(f"Файл {source_file_path} не найден.")

        # Перемещаем файл в директорию назначения
        shutil.copy2(source_file_path, destination_file_path)
        self._log_message(LOG_INFO, f"файл {file_name} успешно перемещен в {destination_dir}.")

    def _make_verifier_request(self, script_name):
        update_verifier_q_name = UPDATE_VARIFIER_QUEUE_NAME 
        
        event_update = Event(
            source=self._events_q_name,
            destination=update_verifier_q_name,
            operation="sign_srcipt",
            parameters=script_name
        )                      

        update_verifier_q: Queue = self._queues_dir.get_queue(update_verifier_q_name)

        update_verifier_q.put(event_update)   
        
        self._log_message(LOG_INFO, f"отправил запрос на подпись программы: {script_name}") 
    
    def _make_updater_request(self, script_name):
        updater_q_name = UPDATER_QUEUE_NAME 
        
        event_update = Event(
            source=self._events_q_name,
            destination=updater_q_name,
            operation="update_srcipt",
            parameters=script_name
        )                      

        updater_q: Queue = self._queues_dir.get_queue(updater_q_name)

        updater_q.put(event_update)   
        
        self._log_message(LOG_INFO, f"отправил запрос на обновление программы: {script_name}")

# %% [markdown]
# ### Теперь еще раз запустим систему, но уже с компонентами, отвечающими за обновление и смотрим на логи

# %%
from time import sleep

from src.queues_dir import QueuesDirectory
from src.servos import Servos
from src.sitl import SITL
from src.cargo_bay import CargoBay
from src.mission_planner import MissionPlanner
from src.config import LOG_ERROR, LOG_INFO
from src.mission_planner_mqtt import MissionSender
from src.mission_planner import Mission
from src.sitl_mqtt import TelemetrySender
from src.system_wrapper import SystemComponentsContainer
from src.wpl_parser import WPLParser

parser = WPLParser(wpl_file)    
points = parser.parse()
print(points)

home = points[0]
mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)

# каталог очередей для передачи сообщений между блоками
queues_dir = QueuesDirectory() 

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

# новые компонениы программы
update_manager = UpdateManager(queues_dir=queues_dir, log_level=LOG_INFO)
user = User(queues_dir=queues_dir, log_level=LOG_INFO)
verifier = Verifier(queues_dir=queues_dir, files_hash_map={'good_script.py': '2367baac16d4c42ebfb541061e8ae3bc97c526c962cfa5a2cab733e23bc02f32'}, log_level=LOG_INFO)
updater = Updater(queues_dir=queues_dir, log_level=LOG_INFO)

communication_gateway = CommunicationGateway(queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)
navigation_system = NavigationSystem(queues_dir=queues_dir, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)

security = SecurityMonitor(queues_dir=queues_dir)

# соберём все компоненты для запуска
# в зависимости от наличия СУПА используем разный набор компонентов - с передачей телеметрии или без

system_components = SystemComponentsContainer(
components=[
        # вариант компонентов с передачей телеметрии в СУПА
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block,
        security,
        update_manager,
        user,
        verifier,
        updater
    ] if afcs_present else [
        # вариант компонентов для конфигурации без СУПА
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block,
        security,
        update_manager,
        user,
        verifier,
        updater
    ])

system_components.start()

# настройте этот параметр так, чтобы проверить работу ограничителя
sleep(170)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# [Point(59.869328, 29.827365, 0.0), Point(59.868883, 29.824322, 0.0), Point(59.869184, 29.823516, 0.0), Point(59.870481, 29.828145, 0.0), Point(59.870456, 29.836566, 0.0), Point(59.869963, 29.844628, 0.0), Point(59.869206, 29.848098, 0.0), Point(59.870235, 29.849917, 0.0), Point(59.870743, 29.849644, 0.0), Point(59.871044, 29.849363, 0.0)]
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь update_manager
# [ИНФО][UPDATE_MANAGER] создана менеджер обновлений
# [ИНФО][QUEUES] регистрируем очередь user_requests
# [ИНФО][USER] создана пользователь
# [ИНФО][QUEUES] регистрируем очередь update_verifier
# [ИНФО][VERIFIER] создана верификатор
# [ИНФО][QUEUES] регистрируем очередь updater
# [ИНФО][UPDATER] создана модуль обновления
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель
# [ИНФО][QUEUES] регистрируем очередь security
# [ИНФО][SECURITY] создан монитор безопасности
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='user_requests', destination='update_manager', operation='update_system'), SecurityPolicy(source='update_manager', destination='update_verifier', operation='sign_srcipt'), SecurityPolicy(source='update_verifier', destination='update_manager', operation='sign_is_done'), SecurityPolicy(source='update_manager', destination='updater', operation='update_srcipt'), SecurityPolicy(source='updater', destination='control', operation='refresh_script'), SecurityPolicy(source='communication', destination='control', operation='set_mission'), SecurityPolicy(source='communication', destination='safety', operation='set_mission'), SecurityPolicy(source='control', destination='safety', operation='set_speed'), SecurityPolicy(source='control', destination='safety', operation='set_direction'), SecurityPolicy(source='control', destination='safety', operation='release_cargo'), SecurityPolicy(source='control', destination='safety', operation='lock_cargo'), SecurityPolicy(source='navigation', destination='safety', operation='position_update'), SecurityPolicy(source='navigation', destination='control', operation='position_update'), SecurityPolicy(source='safety', destination='servos', operation='set_speed'), SecurityPolicy(source='safety', destination='servos', operation='set_direction'), SecurityPolicy(source='safety', destination='cargo', operation='lock_cargo'), SecurityPolicy(source='safety', destination='cargo', operation='release_cargo')]
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][CONTROL] старт системы управления[ИНФО][SAFETY] старт ограничителя
#
# [ИНФО][SECURITY] старт блока грузового отсека
# [ИНФО][UPDATE_MANAGER] старт менеджер обновлений
# [ИНФО][USER] старт пользователь[ИНФО][VERIFIER] старт верификатор
#
# [ИНФО][UPDATER] старт модуль обновления
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 19:02:01.163357
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ СТАРАЯ СКУЧНАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА НИКУДА НЕ ЕДЕТ
# [ИНФО][CONTROL] новая скорость 20 (была 0)
# [ИНФО][CONTROL] новое направление 253 (было 0)
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ СТАРАЯ СКУЧНАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА НИКУДА НЕ ЕДЕТ
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ СТАРАЯ СКУЧНАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА НИКУДА НЕ ЕДЕТ
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ СТАРАЯ СКУЧНАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА НИКУДА НЕ ЕДЕТ
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ СТАРАЯ СКУЧНАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА НИКУДА НЕ ЕДЕТ
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ СТАРАЯ СКУЧНАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА НИКУДА НЕ ЕДЕТ
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ СТАРАЯ СКУЧНАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА НИКУДА НЕ ЕДЕТ
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ СТАРАЯ СКУЧНАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА НИКУДА НЕ ЕДЕТ
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ СТАРАЯ СКУЧНАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА НИКУДА НЕ ЕДЕТ
# [ИНФО][USER] отправил запрос на обновление программы: bad_script.py
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ СТАРАЯ СКУЧНАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА НИКУДА НЕ ЕДЕТ
# [ИНФО][UPDATE_MANAGER] файл bad_script.py успешно перемещен в ./secure_update/destination.
# [ИНФО][UPDATE_MANAGER] отправил запрос на подпись программы: bad_script.py
# [ИНФО][VERIFIER] хеш файла bad_script.py: a7a58d325af55cc0379d2097991b7243f3e463fb24bb09d01427c6f4de0a25f8
# [ОШИБКА][VERIFIER] ошибка верификатор: 'bad_script.py'
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ СТАРАЯ СКУЧНАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА НИКУДА НЕ ЕДЕТ
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ СТАРАЯ СКУЧНАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА НИКУДА НЕ ЕДЕТ
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ СТАРАЯ СКУЧНАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА НИКУДА НЕ ЕДЕТ
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ СТАРАЯ СКУЧНАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА НИКУДА НЕ ЕДЕТ
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ СТАРАЯ СКУЧНАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА НИКУДА НЕ ЕДЕТ
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ СТАРАЯ СКУЧНАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА НИКУДА НЕ ЕДЕТ
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ СТАРАЯ СКУЧНАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА НИКУДА НЕ ЕДЕТ
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ СТАРАЯ СКУЧНАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА НИКУДА НЕ ЕДЕТ
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ СТАРАЯ СКУЧНАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА НИКУДА НЕ ЕДЕТ
# [ИНФО][USER] отправил запрос на обновление программы: good_script.py
# [ИНФО][UPDATE_MANAGER] файл good_script.py успешно перемещен в ./secure_update/destination.
# [ИНФО][UPDATE_MANAGER] отправил запрос на подпись программы: good_script.py
# [ИНФО][VERIFIER] хеш файла good_script.py: 2367baac16d4c42ebfb541061e8ae3bc97c526c962cfa5a2cab733e23bc02f32
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ СТАРАЯ СКУЧНАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА НИКУДА НЕ ЕДЕТ
# [ИНФО][VERIFIER] подпись сохранена в ./secure_update/destination/good_script.py.sign.
# [ИНФО][VERIFIER] файл good_script.py успешно провалидирован.
# [ИНФО][VERIFIER] отправил успешный ответ на подпись: good_script.py
# [ИНФО][UPDATE_MANAGER] отправил запрос на обновление программы: good_script.py
# [ИНФО][UPDATER] подпись файла good_script.py успешно проверена.
# [ИНФО][UPDATER] файл good_script.py успешно перемещен в ./secure_update/executable.
# [ИНФО][UPDATER] отправил запрос на использование новой версии программы: good_script.py
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 0
# [ИНФО][SAFETY] новые координаты: 253.75928369921178
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.5808s N, 29 49m 38.514s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.75928369921178
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.5808s N, 29 49m 38.514s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.75928369921178
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.5808s N, 29 49m 38.514s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.75928369921178
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.5808s N, 29 49m 38.514s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7596574932637
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.5557s N, 29 49m 38.3426s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76004402761203
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.53059s N, 29 49m 38.1712s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.760443929294
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.50549s N, 29 49m 37.9998s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76085786814951
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.48039s N, 29 49m 37.8285s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7612802055091
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.45529s N, 29 49m 37.6571s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7617111553676
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.43018s N, 29 49m 37.4857s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76215093615698
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.40508s N, 29 49m 37.3143s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7625997704738
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.37998s N, 29 49m 37.1429s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7630580006832
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.35488s N, 29 49m 36.9715s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20[ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
#
# [ИНФО][SAFETY] новые координаты: 253.76352598756276
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.32978s N, 29 49m 36.8001s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7640041198986
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.30468s N, 29 49m 36.6288s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76449280696517
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.27958s N, 29 49m 36.4574s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76499248707643
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.25449s N, 29 49m 36.286s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76550362581634
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.22939s N, 29 49m 36.1146s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76602671865072
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.20429s N, 29 49m 35.9432s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76656229073143
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.1792s N, 29 49m 35.7718s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76711090726093
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.15411s N, 29 49m 35.6004s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7676617602319
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.12901s N, 29 49m 35.429s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.76822611860493
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.10392s N, 29 49m 35.2577s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7688046072132
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.07883s N, 29 49m 35.0863s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7693981626787
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.05374s N, 29 49m 34.9149s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7700075413738
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.02865s N, 29 49m 34.7435s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77063355474934
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.00356s N, 29 49m 34.5721s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77127707724856
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.97847s N, 29 49m 34.4007s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77193905198268
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.95339s N, 29 49m 34.2293s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7726204986409
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.9283s N, 29 49m 34.0579s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77332252365375
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.90321s N, 29 49m 33.8865s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77404633422344
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.87813s N, 29 49m 33.7151s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77479324109157
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.85305s N, 29 49m 33.5437s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77556468191375
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.82796s N, 29 49m 33.3723s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77636222994988
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.80288s N, 29 49m 33.2009s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77718761391748
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.7778s N, 29 49m 33.0295s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77804274006985
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.75273s N, 29 49m 32.8581s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77892972048244
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.72765s N, 29 49m 32.6867s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.77985089195232
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.70257s N, 29 49m 32.5153s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.78080886528895
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.6775s N, 29 49m 32.3439s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7818065562144
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.65242s N, 29 49m 32.1725s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.78288284361912
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.62735s N, 29 49m 32.0011s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.7840101619998
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.60228s N, 29 49m 31.8297s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.78519337360285
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.57721s N, 29 49m 31.6583s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.78643805768735
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.55214s N, 29 49m 31.4869s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.78774903819158
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.52707s N, 29 49m 31.3155s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.78913338661232
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.502s N, 29 49m 31.1441s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.79059934702516
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.47694s N, 29 49m 30.9727s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.79215660442006
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.45188s N, 29 49m 30.8013s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.79381674492237
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.42682s N, 29 49m 30.6299s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.79559367568243
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.40176s N, 29 49m 30.4585s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.79710298251308
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.38172s N, 29 49m 30.3214s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.79913423212827
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.35666s N, 29 49m 30.15s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.80131636446964
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.33161s N, 29 49m 29.9785s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.8036987785913
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.30656s N, 29 49m 29.8071s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.8063532047188
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.28152s N, 29 49m 29.6357s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.80930603711857
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.25647s N, 29 49m 29.4643s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.8126308753245
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.23143s N, 29 49m 29.2929s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.81642817812428
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.2064s N, 29 49m 29.1215s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.82083910685532
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.18136s N, 29 49m 28.95s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.82608049134416
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.15634s N, 29 49m 28.7786s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.83249900900455
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.13131s N, 29 49m 28.6072s E
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.84069292655153
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.1063s N, 29 49m 28.4357s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.85180815484114
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.08129s N, 29 49m 28.2643s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.86839383907642
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.05628s N, 29 49m 28.0929s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 253.89377746085728
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.0313s N, 29 49m 27.9214s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 304 (было 253)
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 304.2287504363676
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.00634s N, 29 49m 27.75s E
# [ИНФО][CONTROL] новое направление 306 (было 304)
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 306.4006877804642
# [ИНФО][SAFETY] текущие координаты: 59 52m 7.9814s N, 29 49m 27.5785s E
# [ИНФО][CONTROL] новое направление 308 (было 306)
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 308.7056712500645
# [ИНФО][SAFETY] текущие координаты: 59 52m 7.9565s N, 29 49m 27.407s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 308.94201646048185
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.00699s N, 29 49m 27.2594s E
# [ИНФО][CONTROL] новое направление 309 (было 308)
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 309.0826577139405
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.06025s N, 29 49m 27.1157s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 309.10232287153315
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.11638s N, 29 49m 26.9764s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 309.1094587273011
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.1728s N, 29 49m 26.8376s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 309.1080133592718
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.22938s N, 29 49m 26.699s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 309.1049268665749
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.286s N, 29 49m 26.5605s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 309.1007971647903
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.34262s N, 29 49m 26.422s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 309.0960893330665
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.39923s N, 29 49m 26.2835s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 309.0907947389606
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.45585s N, 29 49m 26.1449s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 309.08483970139486
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.51246s N, 29 49m 26.0064s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 309.0780634826571
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.56906s N, 29 49m 25.8679s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 309.0702232469864
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.62566s N, 29 49m 25.7293s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 309.0609427365249
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.68225s N, 29 49m 25.5908s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 309.0496110386966
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.73883s N, 29 49m 25.4522s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 309.0351517651608
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.7954s N, 29 49m 25.3136s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 309.0154345316579
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.85196s N, 29 49m 25.175s E
# [ИНФО][CONTROL] новое направление 308 (было 309)
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 308.9854292669886
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.90851s N, 29 49m 25.0364s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 60 (была 20)
# [ИНФО][CONTROL] новое направление 59 (было 308)
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 59.9634823474164
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.96504s N, 29 49m 24.8977s E
# [ИНФО][CONTROL] новое направление 60 (было 59)
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 60.46572804295721
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.02155s N, 29 49m 24.759s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 60.9644406134604
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.07802s N, 29 49m 24.6203s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 60.99465165627237
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.2128s N, 29 49m 25.0839s E
# [ИНФО][CONTROL] новое направление 61 (было 60)
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.01172012641564
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.34554s N, 29 49m 25.5498s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.02983048951694
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.47828s N, 29 49m 26.0157s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.033313882165714
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.60897s N, 29 49m 26.484s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.03603450927449
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.73954s N, 29 49m 26.9523s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.0383587649394
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.87004s N, 29 49m 27.4208s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.040208759278244
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.0005s N, 29 49m 27.8893s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.04206240342626
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.1309s N, 29 49m 28.3578s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.043948747484535
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.2613s N, 29 49m 28.8263s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.04588707743949
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.3917s N, 29 49m 29.2949s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.047902971848885
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.522s N, 29 49m 29.7635s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.05000611399606
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.6524s N, 29 49m 30.232s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.051751500679586
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.7567s N, 29 49m 30.6069s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.054019513644675
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.8871s N, 29 49m 31.0755s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.05640287685799
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.0174s N, 29 49m 31.5441s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.05891461992337
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.1478s N, 29 49m 32.0127s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО[ИНФО][SAFETY] новые координаты: 61.06159415860452
#
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.2781s N, 29 49m 32.4813s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.06444039020704
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.4084s N, 29 49m 32.95s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.067476132641616
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.5387s N, 29 49m 33.4186s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.0707291392016
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.669s N, 29 49m 33.8873s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.07423197808845
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.7993s N, 29 49m 34.3559s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.07802670007294
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.9296s N, 29 49m 34.8246s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.082166667188346
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.0599s N, 29 49m 35.2933s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.0867208964068
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.1901s N, 29 49m 35.762s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.09178083747997
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.3204s N, 29 49m 36.2307s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.09747078231379
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.4506s N, 29 49m 36.6995s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.1034503993086
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.5808s N, 29 49m 37.1683s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.11029335293432
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.711s N, 29 49m 37.6371s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.118285459117544
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.8411s N, 29 49m 38.1059s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.12796594136597
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.9712s N, 29 49m 38.5748s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.14019998984463
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.1013s N, 29 49m 39.0437s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.15667616218269
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.2314s N, 29 49m 39.5126s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.181259270126134
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.3614s N, 29 49m 39.9816s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.22567845270555
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.4914s N, 29 49m 40.4506s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 61.354520128614695
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.6213s N, 29 49m 40.9197s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 90 (было 61)
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 90.40954128950261
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7511s N, 29 49m 41.3889s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][CONTROL] новое направление 91 (было 90)
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 90.91287258723048
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.8807s N, 29 49m 41.8583s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.43013724077093
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0098s N, 29 49m 42.3283s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.44924235626735
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0079s N, 29 49m 42.8639s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.46906933859407
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.006s N, 29 49m 43.3994s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.46990441940284
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9992s N, 29 49m 43.9348s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.47039274988941
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9924s N, 29 49m 44.4701s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.47049888299864
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9855s N, 29 49m 45.0055s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.47058957143145
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9786s N, 29 49m 45.5409s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.47067112010512
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9717s N, 29 49m 46.0762s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.47075113231847
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9648s N, 29 49m 46.6116s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.47082984468722
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9579s N, 29 49m 47.147s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.47090737514816
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.951s N, 29 49m 47.6823s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.47098367813663
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9441s N, 29 49m 48.2177s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.4710586972626
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9371s N, 29 49m 48.7531s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.4711323695002
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9302s N, 29 49m 49.2884s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.47120462497884
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9233s N, 29 49m 49.8238s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.47127538949849
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9164s N, 29 49m 50.3592s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 91.47134458315179
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9095s N, 29 49m 50.8945s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# ...
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 32.706621334925615
# [ИНФО][SAFETY] текущие координаты: 59 52m 8.98813s N, 29 50m 54.7658s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 32.21934876752084
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.19254s N, 29 50m 55.1143s E
# [ИНФО][CONTROL] новое направление 31 (было 32)
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 31.868945147384466
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.40597s N, 29 50m 55.4406s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 31.69039194522111
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.62803s N, 29 50m 55.7433s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 31.599283511062822
# [ИНФО][SAFETY] текущие координаты: 59 52m 9.85405s N, 29 50m 56.0343s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 31.543462728012628
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.0816s N, 29 50m 56.3206s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 31.51802489437631
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.3103s N, 29 50m 56.6034s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 31.505268531910247
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.5394s N, 29 50m 56.8847s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 31.499743686768568
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.7688s N, 29 50m 57.1653s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 31.499765581076133
# [ИНФО][SAFETY] текущие координаты: 59 52m 10.9983s N, 29 50m 57.4455s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 31.503388717812186
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.2278s N, 29 50m 57.7254s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 31.51030445598559
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.4574s N, 29 50m 58.0053s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 31.521037780708355
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.687s N, 29 50m 58.2851s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 31.53704749155736
#
# [ИНФО][SAFETY] текущие координаты: 59 52m 11.9166s N, 29 50m 58.5649s E[ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 31.562341664324833
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.1462s N, 29 50m 58.8448s E
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 31.608893491189974
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.3757s N, 29 50m 59.1247s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 60
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 31.733722987441126
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.6053s N, 29 50m 59.4046s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 20 (была 60)
# [ИНФО][CONTROL] новое направление 345 (было 31)
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 60
# [ИНФО][SAFETY] новые координаты: 345.2316087273625
# [ИНФО][SAFETY] текущие координаты: 59 52m 12.8348s N, 29 50m 59.6848s E
# [ИНФО][CONTROL] новое направление 338 (было 345)
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 338.76245909877167
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.0641s N, 29 50m 59.9654s E
# [ИНФО][CONTROL] новое направление 330 (было 338)
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 330.95312482216906
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.2931s N, 29 51m 0.24712s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 330.1025881289656
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.3799s N, 29 51m 0.201615s E
# [ИНФО][CONTROL] новое направление 329 (было 330)
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 329.54948247613027
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.4636s N, 29 51m 0.136951s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 329.4509097368947
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.5421s N, 29 51m 0.0502782s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 329.4001084532897
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.6199s N, 29 50m 59.9613s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 329.3849342051633
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.6973s N, 29 50m 59.8708s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 329.37560579212766
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.7746s N, 29 50m 59.7801s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 329.36929083173504
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.8518s N, 29 50m 59.6892s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 329.3632402162224
# [ИНФО][SAFETY] текущие координаты: 59 52m 13.9291s N, 29 50m 59.5983s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 329.35687107434734
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0063s N, 29 50m 59.5074s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 329.34966559770044
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.0835s N, 29 50m 59.4164s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 329.3412074275298
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.1608s N, 29 50m 59.3255s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 329.3308888662887
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.238s N, 29 50m 59.2345s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 329.3176916508918
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.3152s N, 29 50m 59.1435s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 329.29959840204356
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.3924s N, 29 50m 59.0524s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 329.27178678610585
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.4696s N, 29 50m 58.9614s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 334 (было 329)
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 334.2650408991156
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.5468s N, 29 50m 58.8703s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 334.61633862339613
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.624s N, 29 50m 58.7791s E
# [ИНФО][CONTROL] новое направление 335 (было 334)
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 335.0235828929012
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.7012s N, 29 50m 58.6879s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 335.0836160438554
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.782s N, 29 50m 58.6104s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 335.1226622804876
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.8631s N, 29 50m 58.5339s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 335.1288338928384
# [ИНФО][SAFETY] текущие координаты: 59 52m 14.9445s N, 29 50m 58.4585s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 335.1297148282382
# [ИНФО][SAFETY] текущие координаты: 59 52m 15.0259s N, 29 50m 58.3833s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 335.12594170474813
# [ИНФО][SAFETY] текущие координаты: 59 52m 15.1073s N, 29 50m 58.3082s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 335.12217018159487
# [ИНФО][SAFETY] текущие координаты: 59 52m 15.1724s N, 29 50m 58.2481s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 335.11529355249974
# [ИНФО][SAFETY] текущие координаты: 59 52m 15.2539s N, 29 50m 58.173s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 335.10540190602245
# [ИНФО][SAFETY] текущие координаты: 59 52m 15.3353s N, 29 50m 58.098s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 335.0914783505019
# [ИНФО][SAFETY] текущие координаты: 59 52m 15.4167s N, 29 50m 58.0229s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 335.07003098863487
# [ИНФО][SAFETY] текущие координаты: 59 52m 15.4982s N, 29 50m 57.9478s E
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] новая скорость: 20
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 335.0319195921749
# [ИНФО][SAFETY] текущие координаты: 59 52m 15.5796s N, 29 50m 57.8727s E
# [ИНФО][CONTROL] маршрут пройден, текущее время 19:04:48.234980
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][CONTROL] новая скорость 0.0 (была 20)
# [ИНФО][CONTROL] новое направление 0 (было 335)
# [ИНФО][CONTROL_IMPL] ИСПОЛЬЗУЕТСЯ НОВАЯ ВЕСЕЛАЯ ВЕРСИЯ ПРОГРАММЫ, МАШИНКА ЕДЕТ КУДА НАДО
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] новая скорость: 0.0
# [ИНФО][SAFETY] текущая скорость: 20
# [ИНФО][SAFETY] новые координаты: 0.0
# [ИНФО][SAFETY] текущие координаты: 59 52m 15.661s N, 29 50m 57.7975s E
# [ОШИБКА][SAFETY] Не указана начальная или конечная точка для расчета направления! Остановка.
# [ИНФО][CARGO] выгрузка
# [ИНФО][CARGO] груз оставлен
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 99
#      96 sleep(170)
#      98 # останавливаем все компоненты
# ---> 99 system_components.stop()
#     101 # удалим все созданные компоненты
#     102 system_components.clean()
#
# File /workspaces/cyberimmune-autonomy--chvt-preview/src/system_wrapper.py:39, in SystemComponentsContainer.stop(self)
#      37 for component in self._components:
#      38     self._log_message(LOG_INFO, f"остановка {component.__class__.__name__}")
# ---> 39     component.stop()
#      41 for component in self._components:
#      42     component.join()
#
# AttributeError: 'UpdateManager' object has no attribute 'stop'
